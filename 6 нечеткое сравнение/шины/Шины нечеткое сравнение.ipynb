# %%
import pandas as pd
import numpy as np
import time
import re
from rapidfuzz import process, fuzz
from sentence_transformers import SentenceTransformer, util
from transliterate import translit
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import Normalizer
import gc

# %% [markdown]
# ## Кейс по нечеткому сравнению наименований шин между выгрузками из разных программ с целью подтягивания кодов из 1C
#
# # Алтухов Николай

# %% [markdown]
# Загрузка файла выгрузки, с которым будут сопоставляться наименования из выгрузки из 1C

# %%
df = pd.read_csv('Gr_Krasn.csv',encoding='Windows-1251', low_memory=False)

# %%
df
# Out:
#                                Наименование
# 0         R13 155/70 RoyalBlack Royal ECO
# 1           R13 155/70 RoyalBlack ROYALMILE
# 2             R13 155/70 Sailun Atrezzo Eco
# 3     R13 155/70 Kapsen H202 ComfortMax A/S
# 4                   R13 155/70 Kapsen HD918
# ...                                     ...
# 2381         R21 315/40 ILINK SnowGripper 2
# 2382   R21 315/40 Arivo Winmaster ProX ARW5
# 2383         R22 275/40 ILINK SnowGripper 2
# 2384   R22 275/40 ILINK WinterVorhut Stud 2
# 2385   R22 315/35 ILINK WinterVorhut Stud 2
#
# [2386 rows x 1 columns]

# %% [markdown]
# Загрузка выгрузки из 1C

# %%
df_1C = pd.read_excel('Данные из 1C.xlsx')
df_1C
# Out:
#                                            Наименование          Код
# 0                R13 155/70  75T ROYAL BLACK ROYAL MILE  ЦБ-00007482
# 1                     R13 155/70 75T Sailun ATREZZO ECO  ЦБ-00006440
# 2            R13 155/70  75T KAPSEN H202 ComfortMax A/S  ЦБ-00007311
# 3                       R13 155/70 RoyalBlack Royal A/S  ЦБ-00005134
# 4                      R13 155/70 RoyalBlack Royal Mile  00-00003373
# ...                                                 ...          ...
# 4883  R215/60 Автошина Yokohama 99T XL iceGuard Stud...  ЦБ-00006877
# 4884            R22 275/40 ILINK SNOWGRIPPER II 107H XL  ЦБ-00007606
# 4885       R22 275/40 ILINK WINTERVORHUT STUD Ⅱ 107T XL  ЦБ-00007701
# 4886  R22 285/40 Автошина Nokian Tyres T 110 HKPL 9 ...  ЦБ-00006836
# 4887      R22 315/35 ILINK WINTERVORHUT STUD II 111T XL  ЦБ-00007768
#
# [4888 rows x 2 columns]

# %% [markdown]
# Функции для очистки наименований

# %%
def remove_words_containing(text, substrings):
    # Регулярное выражение для поиска слов, содержащих подстроки
    pattern = r'\b\w*(' + '|'.join([substrings]) + r')\w*\b'
    # Замена слов, содержащих подстроки, на пустую строку
    return re.sub(pattern, '', text)
    
def process_column(df, column_name, new_column_name, substrings_to_remove="шин|овая"):
    # Приведение текста к нижнему регистру
    df[new_column_name] = df[column_name].str.lower()
    # Замена буквы 'ё' на 'е'
    df[new_column_name] = df[new_column_name].str.replace('ё', 'е')

    # Замена символов 'ⅱ' и 'Ⅱ' на 'ii'
    df[new_column_name] = df[new_column_name].str.replace(r'ⅱ|Ⅱ', 'ii', regex=True)

    # Удаление апострофов и скобок
    df[new_column_name] = df[new_column_name].str.replace(r"\(|\)|\'", '', regex=True)
    # Замена всех пробельных символов на пробелы, а также дефиса и нижнего подчеркивания
    df[new_column_name] = df[new_column_name].str.replace(r'\s+|\-|\_',' ', regex=True)
    # Удаление запятых и точек, кроме случаев, когда они находятся в слове или числе (например, запятая останется в значении "8,25")
    df[new_column_name] = df[new_column_name].str.replace(r"(?<!\w),|,(?!\w)|(?<!\w)\.|\.(?!\w)", '', regex=True)
    # Замена запятых на точки
    df[new_column_name] = df[new_column_name].str.replace(r",", '.', regex=True)

    # Удаление слов шина, автошина, легковая, грузовая
    df[new_column_name] = df[new_column_name].apply(lambda x: remove_words_containing(x, substrings_to_remove))
    # Транслитерация
    df[new_column_name] = df[new_column_name].apply(lambda x: translit(x, 'ru', reversed=True))

    # Удаление лишних пробелов
    df[new_column_name] = df[new_column_name].str.replace(r'\s+',' ', regex=True).str.strip()
    return df

# %%
df_1C = process_column(df_1C, 'Наименование', 'Наименование обработанное')
df = process_column(df, 'Наименование', 'Наименование обработанное')

# %% [markdown]
# Шины "Роудстоун" транслитерировались в "roudstoun" (оригинальное название "Roadstone"). Шины "Бриджстоун" - в "bridzhstoun" (ориг. название "bridgestone"). Транслитерированные и оригинальные названия не совсем схожи, но для нечеткого сравнения это намного лучше, чем оставлять русские наименования.

# %%
df_1C[df_1C['Наименование'].str.contains('сто')].sample(n=3, random_state=0)
# Out:
#                                            Наименование          Код  \
# 2771  R14 185/70 Автошина Роудстоун T 92 WINGUARD WI...  ЦБ-00006744
# 2737    R14 185/65 Роудстоун Winguard WinSpike XL (шип)  ЦБ-00006111
# 3169                R15 195/65 Бриджстоун IC7000S (шип)  ЦБ-00006103
#
#                               Наименование обработанное
# 2771  r14 185/70 roudstoun t 92 winguard winspike xl sh
# 2737     r14 185/65 roudstoun winguard winspike xl ship
# 3169                r15 195/65 bridzhstoun ic7000s ship

# %%
df_1C[df_1C['Наименование'].str.contains('sto')].sample(n=3, random_state=1)
# Out:
#                                       Наименование          Код  \
# 1700          R17 235/65 Bridgestone Turanza ER 30  ЦБ-00003840
# 733            R16 205/55 Bridgestone Turanza T001  ЦБ-00002776
# 2896  R15 185/65 Roadstone Winguard WinSpike (шип)  ЦБ-00006251
#
#                         Наименование обработанное
# 1700         r17 235/65 bridgestone turanza er 30
# 733           r16 205/55 bridgestone turanza t001
# 2896  r15 185/65 roadstone winguard winspike ship

# %% [markdown]
# Применение методов нечеткого сравнения token_set_ratio, ratio, WRatio, а также модель "all-distilroberta-v1" для создания эмбеддингов и сравнение с поомщью cos сходства.

# %%
# Замер времени выполнения кода
start_time = time.time()

# Поиск наилучшего совпадения и уровня схожести методом token_set_ratio библиотеки rapidfuzz
# Вычисляет расстояние Левенштейна между двумя множествами токенов, игнорирует порядок слов и дубликаты
def get_token_set_ratio(query, choices):
    match = process.extractOne(query, choices, scorer=fuzz.token_set_ratio)
    if match:
        return match[0], match[1]
    else:
        return None, None

best_matches = df['Наименование обработанное'].apply(lambda x: get_token_set_ratio(x, df_1C['Наименование обработанное']))
df['token_set_ratio уровень сходства'] = best_matches.apply(lambda x: x[1])
df['token_set_ratio лучшее совпадение'] = best_matches.apply(lambda x: x[0])

# Поиск наилучшего совпадения и уровня схожести методом ratio библиотеки rapidfuzz
# Вычисляет расстояние Левенштейна, которое представляет собой минимальное количество односимвольных изменений (вставок, удалений или замен), необходимых для преобразования одной строки в другую
def get_ratio(query, choices):
    match = process.extractOne(query, choices, scorer=fuzz.ratio)
    if match:
        return match[0], match[1]
    else:
        return None, None

best_matches = df['Наименование обработанное'].apply(lambda x: get_ratio(x, df_1C['Наименование обработанное']))
df['ratio уровень сходства'] = best_matches.apply(lambda x: x[1])
df['ratio лучшее совпадение'] = best_matches.apply(lambda x: x[0])

# Поиск наилучшего совпадения и уровня схожести методом WRatio библиотеки rapidfuzz
# Использует предыдущие два метода, после чего взвешивает их результаты (т.е. учитывает различные аспекты строк)
def get_Wratio(query, choices):
    match = process.extractOne(query, choices, scorer=fuzz.WRatio)
    if match:
        return match[0], match[1]
    else:
        return None, None

best_matches = df['Наименование обработанное'].apply(lambda x: get_ratio(x, df_1C['Наименование обработанное']))
df['WRatio уровень сходства'] = best_matches.apply(lambda x: x[1])
df['WRatio лучшее совпадение'] = best_matches.apply(lambda x: x[0])



# Поиск лучшего совпадения с помощью sentence_transformers, используя модель all-distilroberta-v1
model = SentenceTransformer('all-distilroberta-v1')
embeddings1 = model.encode(df['Наименование обработанное'].tolist(), convert_to_tensor=True)
embeddings2 = model.encode(df_1C['Наименование обработанное'].tolist(), convert_to_tensor=True)

similarities = util.pytorch_cos_sim(embeddings1, embeddings2)
best_match_indices = similarities.argmax(dim=1).cpu().numpy()
df['sentence_transformers уровень сходства'] = similarities.max(dim=1).values.cpu().numpy()
df['sentence_transformers уровень сходства'] = df['sentence_transformers уровень сходства']*100
df['sentence_transformers лучшее совпадение'] = df_1C['Наименование обработанное'].iloc[best_match_indices].values

print(f"Время выполнения функции: {time.time() - start_time} секунд")
# Out:
# Время выполнения функции: 67.12573409080505 секунд

# %% [markdown]
# После изучения результатов (будет далее) предыдущих методов было принято решение разработать свой алгоритм для нечеткого сравнения строк.
#
# Алгоритм следующий:
#
# 1) Удаляем из текста все, кроме букв и цифр (даже пробелы удаляются).
# 2) Создаем n-граммы (последовательности из n символов).
# 3) Одна функция будет создавать последовательности из 1, 2, 3 символов. Вторая - из 1, 2, 3, 4 символов.
# 4) Затем подсчитываем количество вхождений каждой n-граммы для каждой строки.
# 5) Применяем косинусное сходство.
# 6) Выделяем по 2 наилучших сходства.

# %%
# Удаляем все кроме букв и цифр
def preprocess_text(text):
    return ''.join(filter(str.isalnum, text.lower()))

# Создаем n-граммы
def create_1_3ngrams(text):
    ngrams = []
    for n in range(1, 4):
        ngrams.extend([text[i:i+n] for i in range(len(text)-n+1)])
    return ngrams
    
def create_1_4ngrams(text):
    ngrams = []
    for n in range(1, 5):
        ngrams.extend([text[i:i+n] for i in range(len(text)-n+1)])
    return ngrams

# %%
df['1-3ngrams'] = df['Наименование обработанное'].apply(lambda x: ' '.join(create_1_3ngrams(preprocess_text(x))))
df['1-4ngrams'] = df['Наименование обработанное'].apply(lambda x: ' '.join(create_1_4ngrams(preprocess_text(x))))

df_1C['1-3ngrams'] = df_1C['Наименование обработанное'].apply(lambda x: ' '.join(create_1_3ngrams(preprocess_text(x))))
df_1C['1-4ngrams'] = df_1C['Наименование обработанное'].apply(lambda x: ' '.join(create_1_4ngrams(preprocess_text(x))))

# %%
combined_1_4ngrams = pd.concat([df_1C['1-4ngrams'], df['1-4ngrams']])
combined_1_3ngrams = pd.concat([df_1C['1-3ngrams'], df['1-3ngrams']])

# Применение CountVectorizer для подсчета вхождений n-грамм
vectorizer_1_4 = CountVectorizer()
combined_count_vec_1_4 = vectorizer_1_4.fit_transform(combined_1_4ngrams)

vectorizer_1_3 = CountVectorizer()
combined_count_vec_1_3 = vectorizer_1_3.fit_transform(combined_1_3ngrams)

# %%
# Нормализация матриц с помощью Normalizer
normalizer_1_3 = Normalizer()
combined_count_vec_1_3_norm = normalizer_1_3.fit_transform(combined_count_vec_1_3)

normalizer_1_4 = Normalizer()
combined_count_vec_1_4_norm = normalizer_1_4.fit_transform(combined_count_vec_1_4)

# %%
count_vec_1_3_df_1C_norm = combined_count_vec_1_3_norm[:len(df_1C)]
count_vec_1_3_df_norm = combined_count_vec_1_3_norm[len(df_1C):]

count_vec_1_4_df_1C_norm = combined_count_vec_1_4_norm[:len(df_1C)]
count_vec_1_4_df_norm = combined_count_vec_1_4_norm[len(df_1C):]

# %%
cos_matrix_1_3 = count_vec_1_3_df_norm.dot(count_vec_1_3_df_1C_norm.T).toarray()
cos_matrix_1_4 = count_vec_1_4_df_norm.dot(count_vec_1_4_df_1C_norm.T).toarray()

# %%
top_2_indices_1_3 = np.argsort(cos_matrix_1_3, axis=1)[:, -2:]
top_2_values_1_3 = np.take_along_axis(cos_matrix_1_3, top_2_indices_1_3, axis=1)
df['Топ1 индекс cos сходства 1_3'] = top_2_indices_1_3[:, -1]
df['Топ2 индекс cos сходства 1_3'] = top_2_indices_1_3[:, -2]
df['Топ1 уровень cos сходства 1_3'] = top_2_values_1_3[:, -1]
df['Топ2 уровень cos сходства 1_3'] = top_2_values_1_3[:, -2]
df['Cos сходство топ1 совпадение 1-3'] = df['Топ1 индекс cos сходства 1_3'].apply(lambda x: df_1C['Наименование обработанное'].iloc[x])
df['Cos сходство топ2 совпадение 1-3'] = df['Топ2 индекс cos сходства 1_3'].apply(lambda x: df_1C['Наименование обработанное'].iloc[x])


top_2_indices_1_4 = np.argsort(cos_matrix_1_4, axis=1)[:, -2:]
top_2_values_1_4 = np.take_along_axis(cos_matrix_1_4, top_2_indices_1_4, axis=1)
df['Топ1 индекс cos сходства 1_4'] = top_2_indices_1_4[:, -1]
df['Топ2 индекс cos сходства 1_4'] = top_2_indices_1_4[:, -2]
df['Топ1 уровень cos сходства 1_4'] = top_2_values_1_4[:, -1]
df['Топ2 уровень cos сходства 1_4'] = top_2_values_1_4[:, -2]
df['Cos сходство топ1 совпадение 1-4'] = df['Топ1 индекс cos сходства 1_4'].apply(lambda x: df_1C['Наименование обработанное'].iloc[x])
df['Cos сходство топ2 совпадение 1-4'] = df['Топ2 индекс cos сходства 1_4'].apply(lambda x: df_1C['Наименование обработанное'].iloc[x])

df['Топ1 уровень cos сходства 1_3'] = df['Топ1 уровень cos сходства 1_3']*100
df['Топ2 уровень cos сходства 1_3'] = df['Топ2 уровень cos сходства 1_3']*100
df['Топ1 уровень cos сходства 1_4'] = df['Топ1 уровень cos сходства 1_4']*100
df['Топ2 уровень cos сходства 1_4'] = df['Топ2 уровень cos сходства 1_4']*100

# %%
df.drop(['Топ1 индекс cos сходства 1_4','Топ2 индекс cos сходства 1_4', 'Топ1 индекс cos сходства 1_3','Топ2 индекс cos сходства 1_3','1-3ngrams', '1-4ngrams'], axis=1, inplace=True)

# %%
df
# Out:
#                                Наименование  \
# 0         R13 155/70 RoyalBlack Royal ECO
# 1           R13 155/70 RoyalBlack ROYALMILE
# 2             R13 155/70 Sailun Atrezzo Eco
# 3     R13 155/70 Kapsen H202 ComfortMax A/S
# 4                   R13 155/70 Kapsen HD918
# ...                                     ...
# 2381         R21 315/40 ILINK SnowGripper 2
# 2382   R21 315/40 Arivo Winmaster ProX ARW5
# 2383         R22 275/40 ILINK SnowGripper 2
# 2384   R22 275/40 ILINK WinterVorhut Stud 2
# 2385   R22 315/35 ILINK WinterVorhut Stud 2
#
#                   Наименование обработанное  token_set_ratio уровень сходства  \
# 0           r13 155/70 royalblack royal eco                         96.774194
# 1           r13 155/70 royalblack royalmile                         87.096774
# 2             r13 155/70 sailun atrezzo eco                        100.000000
# 3     r13 155/70 kapsen h202 comfortmax a/s                        100.000000
# 4                   r13 155/70 kapsen hd918                         88.000000
# ...                                     ...                               ...
# 2381         r21 315/40 ilink snowgripper 2                         96.551724
# 2382   r21 315/40 arivo winmaster prox arw5                        100.000000
# 2383         r22 275/40 ilink snowgripper 2                         96.551724
# 2384   r22 275/40 ilink wintervorhut stud 2                         97.142857
# 2385   r22 315/35 ilink wintervorhut stud 2                         97.142857
#
#                   token_set_ratio лучшее совпадение  ratio уровень сходства  \
# 0                   r13 175/70 royalblack royal eco               96.774194
# 1                   r13 155/70 royalblack royal a/s               98.412698
# 2                 r13 155/70 75t sailun atrezzo eco               93.548387
# 3         r13 155/70 75t kapsen h202 comfortmax a/s               94.871795
# 4                       r13 175/70 82t kapsen hd918               88.000000
# ...                                             ...                     ...
# 2381        r21 315/40 ilink snowgripper ii 115h xl               84.057971
# 2382                 r21 315/40 winmaster prox arw5               90.909091
# 2383        r22 275/40 ilink snowgripper ii 107h xl               84.057971
# 2384  r22 275/40 ilink wintervorhut stud ii 107t xl               89.743590
# 2385  r22 315/35 ilink wintervorhut stud ii 111t xl               87.179487
#
#                          ratio лучшее совпадение  WRatio уровень сходства  \
# 0                r13 175/70 royalblack royal eco                96.774194
# 1               r13 155/70 royalblack royal mile                98.412698
# 2              r13 155/70 75t sailun atrezzo eco                93.548387
# 3      r13 155/70 75t kapsen h202 comfortmax a/s                94.871795
# 4                    r13 175/70 82t kapsen hd918                88.000000
# ...                                          ...                      ...
# 2381     r21 315/40 ilink snowgripper ii 115h xl                84.057971
# 2382              r21 315/40 winmaster prox arw5                90.909091
# 2383     r22 275/40 ilink snowgripper ii 107h xl                84.057971
# 2384  r20 275/40 ilink wintervorhut stud ii 102t                89.743590
# 2385  r20 315/35 ilink wintervorhut stud ii 106t                87.179487
#
#                         WRatio лучшее совпадение  \
# 0                r13 175/70 royalblack royal eco
# 1               r13 155/70 royalblack royal mile
# 2              r13 155/70 75t sailun atrezzo eco
# 3      r13 155/70 75t kapsen h202 comfortmax a/s
# 4                    r13 175/70 82t kapsen hd918
# ...                                          ...
# 2381     r21 315/40 ilink snowgripper ii 115h xl
# 2382              r21 315/40 winmaster prox arw5
# 2383     r22 275/40 ilink snowgripper ii 107h xl
# 2384  r20 275/40 ilink wintervorhut stud ii 102t
# 2385  r20 315/35 ilink wintervorhut stud ii 106t
#
#       sentence_transformers уровень сходства  \
# 0                                  97.717796
# 1                                  95.148521
# 2                                  97.430206
# 3                                  97.726921
# 4                                  95.670876
# ...                                      ...
# 2381                               92.165817
# 2382                               96.218941
# 2383                               91.927757
# 2384                               92.942108
# 2385                               91.863564
#
#             sentence_transformers лучшее совпадение  \
# 0                   r13 175/70 royalblack royal eco
# 1                  r13 155/70 royalblack royal mile
# 2                 r13 155/70 75t sailun atrezzo eco
# 3         r13 155/70 75t kapsen h202 comfortmax a/s
# 4                       r13 175/70 82t kapsen hd918
# ...                                             ...
# 2381        r21 315/35 ilink snowgripper ii 111h xl
# 2382                 r21 315/40 winmaster prox arw5
# 2383        r22 275/40 ilink snowgripper ii 107h xl
# 2384  r22 275/40 ilink wintervorhut stud ii 107t xl
# 2385  r22 315/35 ilink wintervorhut stud ii 111t xl
#
#       Топ1 уровень cos сходства 1_3  Топ2 уровень cos сходства 1_3  \
# 0                         92.063492                      92.063492
# 1                        100.000000                      91.265332
# 2                         87.671401                      80.000000
# 3                         90.112711                      73.929609
# 4                         71.275096                      61.864711
# ...                             ...                            ...
# 2381                      85.052389                      71.993233
# 2382                      85.455020                      68.364016
# 2383                      85.104851                      74.095857
# 2384                      87.228110                      79.014947
# 2385                      85.687647                      81.499096
#
#                    Cos сходство топ1 совпадение 1-3  \
# 0                   r13 175/70 royalblack royal eco
# 1                  r13 155/70 royalblack royal mile
# 2                 r13 155/70 75t sailun atrezzo eco
# 3         r13 155/70 75t kapsen h202 comfortmax a/s
# 4                       r13 175/70 82t kapsen hd918
# ...                                             ...
# 2381        r21 315/40 ilink snowgripper ii 115h xl
# 2382                 r21 315/40 winmaster prox arw5
# 2383        r22 275/40 ilink snowgripper ii 107h xl
# 2384  r22 275/40 ilink wintervorhut stud ii 107t xl
# 2385  r22 315/35 ilink wintervorhut stud ii 111t xl
#
#                 Cos сходство топ2 совпадение 1-3  \
# 0                r13 155/70 royalblack royal a/s
# 1          r13 155/70 75t royal black royal mile
# 2                  r14 185/70 sailun atrezzo eco
# 3     r16 225/70 103t kapsen h202 comfortmax a/s
# 4                    r14 185/70 88h kapsen hd918
# ...                                          ...
# 2381     r21 285/40 ilink snowgripper ii 109h xl
# 2382              r21 275/45 winmaster prox arw5
# 2383     r21 275/40 ilink snowgripper ii 107h xl
# 2384  r20 275/40 ilink wintervorhut stud ii 102t
# 2385  r20 315/35 ilink wintervorhut stud ii 106t
#
#       Топ1 уровень cos сходства 1_4  Топ2 уровень cos сходства 1_4  \
# 0                         91.621541                      90.000000
# 1                        100.000000                      90.131661
# 2                         85.280287                      78.787879
# 3                         88.249750                      71.269665
# 4                         65.079137                      56.907440
# ...                             ...                            ...
# 2381                      84.460955                      69.289103
# 2382                      83.081859                      64.907702
# 2383                      84.503108                      73.214299
# 2384                      86.788931                      78.777340
# 2385                      85.726604                      80.473215
#
#                    Cos сходство топ1 совпадение 1-4  \
# 0                   r13 155/70 royalblack royal a/s
# 1                  r13 155/70 royalblack royal mile
# 2                 r13 155/70 75t sailun atrezzo eco
# 3         r13 155/70 75t kapsen h202 comfortmax a/s
# 4                       r13 175/70 82t kapsen hd918
# ...                                             ...
# 2381        r21 315/40 ilink snowgripper ii 115h xl
# 2382                 r21 315/40 winmaster prox arw5
# 2383        r22 275/40 ilink snowgripper ii 107h xl
# 2384  r22 275/40 ilink wintervorhut stud ii 107t xl
# 2385  r22 315/35 ilink wintervorhut stud ii 111t xl
#
#                 Cos сходство топ2 совпадение 1-4
# 0                r13 175/70 royalblack royal eco
# 1                r13 155/70 royalblack royal a/s
# 2                  r14 175/70 sailun atrezzo eco
# 3     r16 225/70 103t kapsen h202 comfortmax a/s
# 4                    r14 185/70 88h kapsen hd918
# ...                                          ...
# 2381     r21 275/40 ilink snowgripper ii 107h xl
# 2382              r21 275/45 winmaster prox arw5
# 2383     r21 275/40 ilink snowgripper ii 107h xl
# 2384  r20 275/40 ilink wintervorhut stud ii 102t
# 2385  r20 315/35 ilink wintervorhut stud ii 106t
#
# [2386 rows x 18 columns]

# %%
df[(df['WRatio лучшее совпадение']!=df['Cos сходство топ1 совпадение 1-3'])|(df['ratio лучшее совпадение']!=df['Cos сходство топ1 совпадение 1-4'])].sample(20, random_state=29)
# Out:
#                                            Наименование  \
# 1252             R21 325/30 Kapsen RS26 PracticalMax HP
# 46                        R14 175/65 Nokian Nordman SX3
# 1725  R16C 195/75 Viatti 107/105R Vettore Inverno V-...
# 410                    R16 235/70 Nokian Nordman S2 SUV
# 1477          R15 235/75 Triangle Group TR777 Snow Lion
# 790                   R18 225/60 Arivo Traverso ARV H/T
# 1233                         R21 275/40 ILINK L-Zeal 56
# 1189                       R20 275/40 Arivo Ultra ARZ 5
# 1906              R17 225/60 Nokian Hakkapeliitta 8 SUV
# 1449                  R15 195/65 Nokian Hakkapeliitta 8
# 1002             R19 235/50 Kapsen RS26 PracticalMax HP
# 1187                      R20 275/40 Rydanz RALEIGH R06
# 1005                  R19 235/50 Triangle Sportex TH201
# 1848                       R17 225/45 Nokian Nordman 7
# 1267              R13 175/70 Viatti Brina Nordico V-522
# 1585                  R16 215/60 Sailun Ice Blazer WST3
# 1802          R17 215/55 Triangle Group TR777 Snow Lion
# 1946               R17 235/55 ILINK WinterVorhut Stud 2
# 1993                  R17 265/65 Nokian Nordman RS2 SUV
# 2022               R18 225/45 ILINK WinterVorhut Stud 2
#
#                               Наименование обработанное  \
# 1252             r21 325/30 kapsen rs26 practicalmax hp
# 46                        r14 175/65 nokian nordman sx3
# 1725  r16c 195/75 viatti 107/105r vettore inverno v 524
# 410                    r16 235/70 nokian nordman s2 suv
# 1477          r15 235/75 triangle group tr777 snow lion
# 790                   r18 225/60 arivo traverso arv h/t
# 1233                         r21 275/40 ilink l zeal 56
# 1189                       r20 275/40 arivo ultra arz 5
# 1906              r17 225/60 nokian hakkapeliitta 8 suv
# 1449                  r15 195/65 nokian hakkapeliitta 8
# 1002             r19 235/50 kapsen rs26 practicalmax hp
# 1187                      r20 275/40 rydanz raleigh r06
# 1005                  r19 235/50 triangle sportex th201
# 1848                        r17 225/45 nokian nordman 7
# 1267              r13 175/70 viatti brina nordico v 522
# 1585                  r16 215/60 sailun ice blazer wst3
# 1802          r17 215/55 triangle group tr777 snow lion
# 1946               r17 235/55 ilink wintervorhut stud 2
# 1993                  r17 265/65 nokian nordman rs2 suv
# 2022               r18 225/45 ilink wintervorhut stud 2
#
#       token_set_ratio уровень сходства  \
# 1252                         95.890411
# 46                          100.000000
# 1725                        100.000000
# 410                          95.238095
# 1477                         86.363636
# 790                          90.000000
# 1233                         80.000000
# 1189                         81.632653
# 1906                         94.594595
# 1449                        100.000000
# 1002                         95.890411
# 1187                        100.000000
# 1005                         88.372093
# 1848                         96.296296
# 1267                        100.000000
# 1585                        100.000000
# 1802                        100.000000
# 1946                         97.142857
# 1993                         96.969697
# 2022                         97.142857
#
#                       token_set_ratio лучшее совпадение  \
# 1252    r21 325/30 xl 108w kapsen rs26 practicalmax h/p
# 46             r14 175/65 nokian tyres t 82 nordman sx3
# 1725                           r16c 195/75 viatti v 524
# 410                     r16 215/70 nokian nordman s suv
# 1477                          r15 235/75 triangle tr258
# 790                 r18 225/60 104h xl traverso arv h/t
# 1233                      r19 235/45 ilink l zeal56 95w
# 1189                              r20 275/45 ultra arz5
# 1906              r17 235/65 nokian hakkapeliitta 8 suv
# 1449             r15 195/65 nokian hakkapeliitta 8 ship
# 1002    r19 235/50 xl 103w kapsen rs26 practicalmax h/p
# 1187              r20 275/40 106w xl rydanz raleigh r06
# 1005                           r19 235/50 triangle pl02
# 1848                        r17 215/45 nokian nordman 7
# 1267      r13 175/70 viatti t 82 brina nordico v 522 sh
# 1585      r16 215/60 sailun ice blazer wst3 99t xl ship
# 1802                          r17 215/55 triangle tr777
# 1946  r17 235/55 ilink wintervorhut stud ii 103t xl ...
# 1993                  r17 225/65 nokian nordman rs2 suv
# 2022  r18 225/45 ilink wintervorhut stud ii 95t xl ship
#
#       ratio уровень сходства                        ratio лучшее совпадение  \
# 1252               90.909091        r20 265/50 kapsen rs26 practical max hp
# 46                 91.228070                   r15 195/65 nokian nordman sx
# 1725               87.234043  r16c 195/75 viatti107/105 vettore brina v 525
# 410                95.238095                r16 215/70 nokian nordman s suv
# 1477               76.315789            r18 225/55 triangle group snow pl01
# 790                86.666667                    r18 235/60 traverso arv h/t
# 1233               81.355932              r21 275/50 ilink l zeal56 113v xl
# 1189               81.632653                          r20 245/40 ultra arz5
# 1906               94.594595          r17 235/65 nokian hakkapeliitta 8 suv
# 1449               93.939394              r15 195/65 nokian hakkapiilitta 8
# 1002               90.909091        r20 265/50 kapsen rs26 practical max hp
# 1187               88.888889             r20 275/60 115h rydanz raleigh r06
# 1005               82.758621                      r19 235/35 triangle th201
# 1848               96.296296                    r17 215/45 nokian nordman 7
# 1267               90.410959           r15 195/60 viatti brina nordico v522
# 1585               90.909091              r17 215/50 sailun ice blazer wst1
# 1802               78.947368            r18 225/55 triangle group snow pl01
# 1946               85.000000   r17 215/55 ilink wintervorhut stud ii 98t xl
# 1993               96.969697              r17 225/65 nokian nordman rs2 suv
# 2022               85.000000   r17 225/45 ilink wintervorhut stud ii 94h xl
#
#       WRatio уровень сходства                       WRatio лучшее совпадение  \
# 1252                90.909091        r20 265/50 kapsen rs26 practical max hp
# 46                  91.228070                   r15 195/65 nokian nordman sx
# 1725                87.234043  r16c 195/75 viatti107/105 vettore brina v 525
# 410                 95.238095                r16 215/70 nokian nordman s suv
# 1477                76.315789            r18 225/55 triangle group snow pl01
# 790                 86.666667                    r18 235/60 traverso arv h/t
# 1233                81.355932              r21 275/50 ilink l zeal56 113v xl
# 1189                81.632653                          r20 245/40 ultra arz5
# 1906                94.594595          r17 235/65 nokian hakkapeliitta 8 suv
# 1449                93.939394              r15 195/65 nokian hakkapiilitta 8
# 1002                90.909091        r20 265/50 kapsen rs26 practical max hp
# 1187                88.888889             r20 275/60 115h rydanz raleigh r06
# 1005                82.758621                      r19 235/35 triangle th201
# 1848                96.296296                    r17 215/45 nokian nordman 7
# 1267                90.410959           r15 195/60 viatti brina nordico v522
# 1585                90.909091              r17 215/50 sailun ice blazer wst1
# 1802                78.947368            r18 225/55 triangle group snow pl01
# 1946                85.000000   r17 215/55 ilink wintervorhut stud ii 98t xl
# 1993                96.969697              r17 225/65 nokian nordman rs2 suv
# 2022                85.000000   r17 225/45 ilink wintervorhut stud ii 94h xl
#
#       sentence_transformers уровень сходства  \
# 1252                               92.199516
# 46                                 95.181915
# 1725                               95.869583
# 410                                92.998634
# 1477                               81.163895
# 790                                93.430672
# 1233                               90.096024
# 1189                               91.758797
# 1906                               94.773033
# 1449                               98.587837
# 1002                               92.752121
# 1187                               93.293793
# 1005                               80.868958
# 1848                               97.706345
# 1267                               95.645210
# 1585                               94.938660
# 1802                               81.894379
# 1946                               93.013115
# 1993                               98.395554
# 2022                               93.593323
#
#             sentence_transformers лучшее совпадение  \
# 1252        r20 265/50 kapsen rs26 practical max hp
# 46                    r14 175/70 nokian nordman sx2
# 1725       r16c 205/65 viatti vettore inverno v 524
# 410                 r16 245/70 nokian nordman s suv
# 1477                      r15 205/70 triangle tr777
# 790                     r18 235/60 traverso arv h/t
# 1233            r21 275/45 ilink l zeal56 110w xl z
# 1189                          r20 275/45 ultra arz5
# 1906          r17 235/65 nokian hakkapeliitta 8 suv
# 1449              r15 195/65 nokian hakkapiilitta 8
# 1002        r20 265/50 kapsen rs26 practical max hp
# 1187             r20 275/60 115h rydanz raleigh r06
# 1005                      r19 225/40 triangle th201
# 1848                    r17 215/45 nokian nordman 7
# 1267          r15 205/70 viatti brina nordico v 523
# 1585              r17 215/50 sailun ice blazer wst1
# 1802                      r17 225/55 triangle tr777
# 1946  r17 225/55 ilink wintervorhut stud ii 101h xl
# 1993              r17 235/65 nokian nordman rs2 suv
# 2022   r18 225/50 ilink wintervorhut stud ii 99t xl
#
#       Топ1 уровень cos сходства 1_3  Топ2 уровень cos сходства 1_3  \
# 1252                      86.916383                      79.042540
# 46                        81.632653                      81.508540
# 1725                      82.908117                      81.116704
# 410                       82.707603                      82.707603
# 1477                      60.163557                      56.911878
# 790                       73.994007                      72.549020
# 1233                      75.153823                      74.520394
# 1189                      73.951790                      67.441860
# 1906                      85.887577                      83.050847
# 1449                      93.212256                      89.694812
# 1002                      86.916383                      84.271225
# 1187                      83.451893                      78.979850
# 1005                      68.646771                      65.487619
# 1848                      93.500357                      88.888889
# 1267                      87.381386                      81.046530
# 1585                      85.972695                      79.894350
# 1802                      74.304285                      74.304285
# 1946                      82.917853                      80.922150
# 1993                      91.085952                      91.085952
# 2022                      83.490162                      80.343022
#
#                        Cos сходство топ1 совпадение 1-3  \
# 1252    r21 325/30 xl 108w kapsen rs26 practicalmax h/p
# 46                        r14 175/70 nokian nordman sx2
# 1725  r16c 195/75 viatti vettore inverno zima v 524 ...
# 410                     r16 265/70 nokian nordman s suv
# 1477                          r15 235/75 triangle tr258
# 790                         r18 255/60 traverso arv h/t
# 1233                  r21 275/50 ilink l zeal56 113v xl
# 1189                              r20 275/45 ultra arz5
# 1906         r17 225/65 nokian hakkapeliitta 8 suv ship
# 1449             r15 195/65 nokian hakkapeliitta 8 ship
# 1002    r19 235/50 xl 103w kapsen rs26 practicalmax h/p
# 1187              r20 275/40 106w xl rydanz raleigh r06
# 1005                          r19 255/50 triangle th201
# 1848                       r17 225/45 nokian nordman sz
# 1267      r13 175/70 viatti t 82 brina nordico v 522 sh
# 1585      r16 215/60 sailun ice blazer wst3 99t xl ship
# 1802                         r17 215/55 triangle tr 777
# 1946  r17 235/55 ilink wintervorhut stud ii 103t xl ...
# 1993                  r17 235/65 nokian nordman rs2 suv
# 2022  r18 225/45 ilink wintervorhut stud ii 95t xl ship
#
#                      Cos сходство топ2 совпадение 1-3  \
# 1252          r20 265/50 kapsen rs26 practical max hp
# 46           r14 175/65 nokian tyres t 82 nordman sx3
# 1725    r16c 195/75 viatti vettore inverno v 524 ship
# 410                   r16 245/70 nokian nordman s suv
# 1477                        r15 205/65 triangle tr777
# 790               r18 225/60 104h xl traverso arv h/t
# 1233              r20 275/40 ilink l zeal56 106w xl z
# 1189                    r20 275/40 106w xl ultra arz5
# 1906            r17 235/65 nokian hakkapeliitta 8 suv
# 1449           r15 195/65 nokian hakkapeliitta 9 ship
# 1002  r19 255/50 kapsen rs26 practicalmax h/p 107w xl
# 1187            r20 275/45 110v xl rydanz raleigh r06
# 1005                         r19 235/50 triangle pl02
# 1848                      r17 215/45 nokian nordman 7
# 1267            r15 205/70 viatti brina nordico v 523
# 1585       r16 205/60 sailun ice blazer wst3 96t ship
# 1802                        r17 215/55 triangle tr777
# 1946     r17 215/55 ilink wintervorhut stud ii 98t xl
# 1993                r17 225/65 nokian nordman rs2 suv
# 2022     r17 225/45 ilink wintervorhut stud ii 94h xl
#
#       Топ1 уровень cos сходства 1_4  Топ2 уровень cos сходства 1_4  \
# 1252                      85.201287                      78.026689
# 46                        78.898188                      78.571429
# 1725                      79.567831                      78.884265
# 410                       77.868134                      77.868134
# 1477                      58.585010                      51.214752
# 790                       69.800230                      67.748454
# 1233                      72.887930                      72.168784
# 1189                      70.048626                      64.002048
# 1906                      84.046064                      80.459770
# 1449                      93.094934                      89.514359
# 1002                      85.201287                      83.521527
# 1187                      80.967111                      76.553182
# 1005                      64.715023                      64.715023
# 1848                      93.154201                      85.937500
# 1267                      85.533720                      80.005537
# 1585                      85.749293                      77.781746
# 1802                      71.105713                      71.105713
# 1946                      82.373004                      78.689960
# 1993                      88.756934                      88.756934
# 2022                      83.099780                      79.304050
#
#                        Cos сходство топ1 совпадение 1-4  \
# 1252    r21 325/30 xl 108w kapsen rs26 practicalmax h/p
# 46             r14 175/65 nokian tyres t 82 nordman sx3
# 1725      r16c 195/75 viatti vettore inverno v 524 ship
# 410                     r16 215/70 nokian nordman s suv
# 1477                          r15 235/75 triangle tr258
# 790                 r18 225/60 104h xl traverso arv h/t
# 1233                r20 275/40 ilink l zeal56 106w xl z
# 1189                              r20 275/45 ultra arz5
# 1906         r17 225/65 nokian hakkapeliitta 8 suv ship
# 1449             r15 195/65 nokian hakkapeliitta 8 ship
# 1002    r19 235/50 xl 103w kapsen rs26 practicalmax h/p
# 1187              r20 275/40 106w xl rydanz raleigh r06
# 1005                           r19 235/50 triangle pl02
# 1848                       r17 225/45 nokian nordman sz
# 1267      r13 175/70 viatti t 82 brina nordico v 522 sh
# 1585      r16 215/60 sailun ice blazer wst3 99t xl ship
# 1802                          r17 215/55 triangle tr777
# 1946  r17 235/55 ilink wintervorhut stud ii 103t xl ...
# 1993                  r17 225/65 nokian nordman rs2 suv
# 2022  r18 225/45 ilink wintervorhut stud ii 95t xl ship
#
#                        Cos сходство топ2 совпадение 1-4
# 1252            r20 265/50 kapsen rs26 practical max hp
# 46                        r14 175/70 nokian nordman sx2
# 1725  r16c 195/75 viatti vettore inverno zima v 524 ...
# 410                     r16 225/70 nokian nordman s suv
# 1477                          r15 205/65 triangle tr777
# 790                         r18 255/60 traverso arv h/t
# 1233                  r21 275/50 ilink l zeal56 113v xl
# 1189                      r20 275/40 106w xl ultra arz5
# 1906              r17 235/65 nokian hakkapeliitta 8 suv
# 1449             r15 195/65 nokian hakkapeliitta 9 ship
# 1002            r20 265/50 kapsen rs26 practical max hp
# 1187              r20 275/45 110v xl rydanz raleigh r06
# 1005                          r19 235/50 triangle pl 02
# 1848                        r17 215/45 nokian nordman 7
# 1267              r15 205/70 viatti brina nordico v 523
# 1585         r16 205/60 sailun ice blazer wst3 96t ship
# 1802                         r17 215/55 triangle tr 777
# 1946       r17 215/55 ilink wintervorhut stud ii 98t xl
# 1993                  r17 235/65 nokian nordman rs2 suv
# 2022       r17 225/45 ilink wintervorhut stud ii 94h xl

# %% [markdown]
# ### Как можно заметить, методы ratio, WRatio и sentence_transformers значительно хуже показали себя в сравнении с остальными, поэтому их удалим и сделаем взвешенное решение на основе оставшихся трех методов

# %%
df_remaining = df.iloc[:,[1,2,3,-8,-7,-6,-5,-4,-3,-2,-1]].copy()
df_remaining = df_remaining.round(3)

# %%
df_remaining.sample()
# Out:
#             Наименование обработанное  token_set_ratio уровень сходства  \
# 1756  r17 215/45 massimo mas winter79                            83.019
#
#              token_set_ratio лучшее совпадение  Топ1 уровень cos сходства 1_3  \
# 1756  r17 215/45 massimo mas winter 79 91 v xl                         91.987
#
#       Топ2 уровень cos сходства 1_3          Cos сходство топ1 совпадение 1-3  \
# 1756                         86.322  r17 215/45 massimo mas winter 79 91 v xl
#
#            Cos сходство топ2 совпадение 1-3  Топ1 уровень cos сходства 1_4  \
# 1756  r17 225/45 massimo mas winter 79 94 v                         91.581
#
#       Топ2 уровень cos сходства 1_4          Cos сходство топ1 совпадение 1-4  \
# 1756                         83.761  r17 215/45 massimo mas winter 79 91 v xl
#
#            Cos сходство топ2 совпадение 1-4
# 1756  r17 225/45 massimo mas winter 79 94 v

# %%
df_remaining[~(df_remaining['Cos сходство топ1 совпадение 1-3']==df_remaining['Cos сходство топ1 совпадение 1-4'])]
# Out:
#                     Наименование обработанное  \
# 0             r13 155/70 royalblack royal eco
# 25          r13 175/70 pirelli formula energy
# 33            r14 175/65 royalblack royalmile
# 35                 r14 175/65 ilink l grip 55
# 46              r14 175/65 nokian nordman sx3
# ...                                       ...
# 2318           r20 255/50 kapsen icemax rw501
# 2335         r20 275/45 kapsen snowshoes aw33
# 2341  r20 275/45 yokohama ice guard stud ig55
# 2342              r20 275/75 pirelli ice zero
# 2356    r20 285/50 nokian hakkapeliitta 8 suv
#
#       token_set_ratio уровень сходства  \
# 0                               96.774
# 25                              90.909
# 33                              87.097
# 35                              80.000
# 46                             100.000
# ...                                ...
# 2318                            77.551
# 2335                            84.615
# 2341                            83.582
# 2342                            85.185
# 2356                           100.000
#
#                       token_set_ratio лучшее совпадение  \
# 0                       r13 175/70 royalblack royal eco
# 25                    r14 175/65 pirelli formula energy
# 33                      r14 175/65 royalblack royal eco
# 35                        r15 185/65 ilink l grip55 88h
# 46             r14 175/65 nokian tyres t 82 nordman sx3
# ...                                                 ...
# 2318                    r19 255/50 kapsen rw501 107h xl
# 2335                     r20 275/45 xl kapsen aw33 110h
# 2341       r16 195/55 yokohama ice guard stud ig55 ship
# 2342                        r17 215/50 pirelli ice zero
# 2356  r20 285/50 nokian tyres116t xl hakkapeliitta 8...
#
#       Топ1 уровень cos сходства 1_3  Топ2 уровень cos сходства 1_3  \
# 0                            92.063                         92.063
# 25                           77.358                         75.472
# 33                           91.265                         90.636
# 35                           70.198                         70.198
# 46                           81.633                         81.509
# ...                             ...                            ...
# 2318                         58.824                         57.191
# 2335                         56.360                         52.185
# 2341                         77.069                         77.049
# 2342                         65.184                         64.304
# 2356                         76.345                         75.600
#
#                  Cos сходство топ1 совпадение 1-3  \
# 0                 r13 175/70 royalblack royal eco
# 25              r14 175/65 pirelli formula energy
# 33          r14 175/65 82t royal black royal mile
# 35                  r15 205/65 ilink l grip55 94v
# 46                  r14 175/70 nokian nordman sx2
# ...                                           ...
# 2318              r19 255/50 kapsen rw501 107h xl
# 2335               r20 275/45 xl kapsen aw33 110h
# 2341  r17 275/65 yokohama iceguard stud ig55 ship
# 2342                    r20 275/40 pirelli s zero
# 2356   r18 285/60 nokian hakkapeliitta 8 suv ship
#
#                        Cos сходство топ2 совпадение 1-3  \
# 0                       r13 155/70 royalblack royal a/s
# 25                    r14 185/60 pirelli formula energy
# 33                      r14 175/65 royalblack royal eco
# 35                        r15 185/65 ilink l grip55 88h
# 46             r14 175/65 nokian tyres t 82 nordman sx3
# ...                                                 ...
# 2318                     r20 255/50 kapsen aw33 109h xl
# 2335                       r20 275/45 kapsen rw501 110h
# 2341            r17 235/45 yokohama iceguard stud ig 65
# 2342                        r14 185/65 pirelli ice zero
# 2356  r20 285/50 nokian tyres116t xl hakkapeliitta 8...
#
#       Топ1 уровень cos сходства 1_4  Топ2 уровень cos сходства 1_4  \
# 0                            91.622                         90.000
# 25                           74.359                         74.359
# 33                           89.630                         89.326
# 35                           68.579                         68.579
# 46                           78.898                         78.571
# ...                             ...                            ...
# 2318                         55.354                         54.795
# 2335                         51.560                         51.168
# 2341                         76.667                         75.147
# 2342                         63.943                         63.943
# 2356                         74.587                         74.348
#
#               Cos сходство топ1 совпадение 1-4  \
# 0              r13 155/70 royalblack royal a/s
# 25           r15 195/50 pirelli formula energy
# 33             r14 175/65 royalblack royal eco
# 35               r15 185/65 ilink l grip55 88h
# 46    r14 175/65 nokian tyres t 82 nordman sx3
# ...                                        ...
# 2318            r20 255/50 kapsen aw33 109h xl
# 2335              r20 275/45 kapsen rw501 110h
# 2341   r17 235/45 yokohama iceguard stud ig 65
# 2342               r17 225/45 pirelli ice zero
# 2356    r17 215/50 nokian hakkapeliitta 8 ship
#
#                  Cos сходство топ2 совпадение 1-4
# 0                 r13 175/70 royalblack royal eco
# 25              r14 175/65 pirelli formula energy
# 33          r14 175/65 82t royal black royal mile
# 35                  r16 215/65 ilink l grip55 98h
# 46                  r14 175/70 nokian nordman sx2
# ...                                           ...
# 2318              r19 255/50 kapsen rw501 107h xl
# 2335               r20 275/45 xl kapsen aw33 110h
# 2341  r17 275/65 yokohama iceguard stud ig55 ship
# 2342                  r14 185/65 pirelli ice zero
# 2356   r18 285/60 nokian hakkapeliitta 8 suv ship
#
# [161 rows x 11 columns]

# %%
df_remaining[~((df_remaining['Cos сходство топ1 совпадение 1-3']==df_remaining['Cos сходство топ1 совпадение 1-4'])|(df_remaining['Cos сходство топ2 совпадение 1-3']==df_remaining['Cos сходство топ1 совпадение 1-4']))]
# Out:
#                         Наименование обработанное  \
# 25              r13 175/70 pirelli formula energy
# 219         r15 205/70 kapsen h201 touringmax a/s
# 410              r16 235/70 nokian nordman s2 suv
# 428             r16 265/70 royalblack royal sport
# 659                 r17 235/45 sailun atrezzo zsr
# 675                   r17 235/65 sunwide conquest
# 678                  r17 235/65 massimo stella s2
# 695                  r17 245/40 arivo ultra arz 4
# 738                r18 215/55 kapsen k3000 papide
# 761              r18 225/45 kapsen s2000 headking
# 999             r19 235/40 triangle sportex th201
# 1068                   r19 255/45 ilink l zeal 56
# 1107            r19 275/35 triangle sportex th201
# 1146       r20 255/35 royalblack royal perfomance
# 1147                   r20 255/35 ilink l zeal 56
# 1317               r14 185/60 pirelli formula ice
# 1319                r14 185/60 nokian nordman rs2
# 1393               r15 185/65 pirelli formula ice
# 1446                r15 195/65 nokian nordman rs2
# 1582              r16 215/55 nokian hakapelitta 8
# 1666    r16 225/70 triangle group tr777 snow lion
# 1684            r16 235/70 nokian nordman rs2 suv
# 1744  r16c 235/65 sailun 115/113r ice blazer wst1
# 1764    r17 215/45 triangle group tr777 snow lion
# 1939    r17 235/45 triangle group tr777 snow lion
# 1942    r17 235/55 triangle group tr777 snow lion
# 2224          r19 245/45 triangle group trin pl02
# 2257               r19 255/50 triangle group pl02
# 2290            r19 275/40 nokian hakkapeliitta 8
# 2296              r20 235/55 triangle group tr797
# 2342                  r20 275/75 pirelli ice zero
# 2356        r20 285/50 nokian hakkapeliitta 8 suv
#
#       token_set_ratio уровень сходства  \
# 25                              90.909
# 219                             64.516
# 410                             95.238
# 428                            100.000
# 659                            100.000
# 675                             92.000
# 678                             70.000
# 695                             77.551
# 738                             92.857
# 761                             93.333
# 999                             91.304
# 1068                            87.273
# 1107                            91.304
# 1146                           100.000
# 1147                            82.759
# 1317                            92.857
# 1319                            96.552
# 1393                            92.857
# 1446                           100.000
# 1582                            90.625
# 1666                            86.364
# 1684                            93.750
# 1744                            88.372
# 1764                            88.372
# 1939                            90.566
# 1942                            86.364
# 2224                            90.909
# 2257                            86.364
# 2290                            87.879
# 2296                            75.000
# 2342                            85.185
# 2356                           100.000
#
#                       token_set_ratio лучшее совпадение  \
# 25                    r14 175/65 pirelli formula energy
# 219                               r15 205/70 ahiles 122
# 410                     r16 215/70 nokian nordman s suv
# 428              r16 265/70 112h royalblack royal sport
# 659                   r17 235/45 97y sailun atrezzo zsr
# 675                    r18 235/65 sunwide conquest 106h
# 678                    r17 235/45 97w massimo ottima p1
# 695                               r17 205/40 ultra arz4
# 738               r16 215/55 xl 97w kapsen k3000 papide
# 761             r17 225/45 xl 94w kapsen s2000 headking
# 999                           r18 235/40 triangle th201
# 1068                      r19 235/45 ilink l zeal56 95w
# 1107                          r20 275/35 triangle th201
# 1146      r20 255/35 97w xl royalblack royal perfomance
# 1147                   r20 245/35 ilink l zeal56 95w xl
# 1317                  r14 185/60 pirelli formula energy
# 1319                      r14 185/60 nokian nordman sx2
# 1393                  r15 185/65 pirelli formula energy
# 1446            r15 195/65 nokian nordman rs2 otsrochka
# 1582                  r16 205/55 nokian hakkapiilitta 8
# 1666                          r16 225/70 triangle tr257
# 1684                    r16 215/70 nokian nordman s suv
# 1744        r16c 215/75 116/114r sailun ice blazer wsl1
# 1764                           r17 215/45 triangle pl01
# 1939                      r17 235/45 triangle snow pl01
# 1942                          r17 235/55 triangle th201
# 2224                           r18 245/45 triangle pl02
# 2257                          r19 255/50 triangle th201
# 2290                  r16 235/70 nokian hakkapeliitta 7
# 2296                          r17 235/55 triangle th201
# 2342                        r17 215/50 pirelli ice zero
# 2356  r20 285/50 nokian tyres116t xl hakkapeliitta 8...
#
#       Топ1 уровень cos сходства 1_3  Топ2 уровень cos сходства 1_3  \
# 25                           77.358                         75.472
# 219                          45.926                         45.763
# 410                          82.708                         82.708
# 428                          92.537                         92.537
# 659                          88.889                         88.889
# 675                          81.694                         81.145
# 678                          47.741                         47.717
# 695                          65.735                         65.735
# 738                          77.876                         77.876
# 761                          78.372                         78.248
# 999                          68.185                         68.185
# 1068                         80.874                         80.226
# 1107                         68.647                         68.185
# 1146                         93.506                         93.506
# 1147                         76.736                         75.370
# 1317                         82.607                         82.607
# 1319                         89.796                         89.796
# 1393                         82.607                         82.607
# 1446                         89.796                         89.796
# 1582                         77.898                         77.624
# 1666                         64.255                         64.255
# 1684                         78.182                         77.414
# 1744                         61.435                         61.124
# 1764                         64.255                         64.255
# 1939                         64.255                         64.255
# 1942                         65.459                         65.459
# 2224                         68.592                         68.351
# 2257                         70.457                         70.457
# 2290                         72.235                         72.108
# 2296                         60.747                         60.747
# 2342                         65.184                         64.304
# 2356                         76.345                         75.600
#
#                  Cos сходство топ1 совпадение 1-3  \
# 25              r14 175/65 pirelli formula energy
# 219     r13 155/70 75t kapsen h202 comfortmax a/s
# 410               r16 265/70 nokian nordman s suv
# 428             r16 245/70 royalblack royal sport
# 659                 r18 235/45 sailun atrezzo zsr
# 675              r17 265/65 sunwide conquest 112h
# 678                     r17 235/65 winmaster arw2
# 695                         r18 245/40 ultra arz4
# 738         r16 215/55 xl 97w kapsen k3000 papide
# 761      r18 255/45 xl 103w kapsen s2000 headking
# 999                     r19 255/40 triangle th201
# 1068                r19 245/45 ilink l zeal56 98w
# 1107                    r19 235/35 triangle th201
# 1146       r20 255/45 royalblack royal perfomance
# 1147             r20 245/35 ilink l zeal56 95w xl
# 1317          r15 185/60 pirelli formula ice ship
# 1319                r14 185/65 nokian nordman rs2
# 1393          r14 185/65 pirelli formula ice ship
# 1446                r15 185/65 nokian nordman rs2
# 1582           r16 205/55 nokian hakkapeliitta r2
# 1666                    r16 215/70 triangle tr777
# 1684            r17 235/65 nokian nordman rs2 suv
# 1744  r16c 215/75 116/114r sailun ice blazer wsl1
# 1764                   r17 225/45 triangle tr 777
# 1939                    r17 225/45 triangle tr777
# 1942                   r17 225/55 triangle tr 777
# 2224                     r18 245/45 triangle pl02
# 2257                     r19 235/50 triangle pl02
# 2290           r16 195/50 nokian hakkapeliitta r2
# 2296                    r19 235/55 triangle tr259
# 2342                    r20 275/40 pirelli s zero
# 2356   r18 285/60 nokian hakkapeliitta 8 suv ship
#
#                        Cos сходство топ2 совпадение 1-3  \
# 25                    r14 185/60 pirelli formula energy
# 219                r16 205/60 kapsen comfortmax as h202
# 410                     r16 245/70 nokian nordman s suv
# 428                   r16 225/70 royalblack royal sport
# 659                       r17 225/45 sailun atrezzo zsr
# 675                    r17 225/65 sunwide conquest 102h
# 678               r14 175/65 massimo mas winter 79 82 t
# 695                               r17 205/40 ultra arz4
# 738               r17 215/55 xl 98w kapsen k3000 papide
# 761            r18 245/45 xl 100w kapsen s2000 headking
# 999                           r18 235/40 triangle th201
# 1068                      r19 235/45 ilink l zeal56 95w
# 1107                          r19 255/35 triangle th201
# 1146             r20 245/35 royalblack royal perfomance
# 1147                r20 275/35 ilink l zeal56 102w xl z
# 1317                r14 185/70 pirelli formula ice ship
# 1319                      r15 185/60 nokian nordman rs2
# 1393                r15 185/60 pirelli formula ice ship
# 1446                      r15 195/60 nokian nordman rs2
# 1582             r16 225/55 nokian hakkapeliitta 8 ship
# 1666                         r16 215/70 triangle tr 777
# 1684                    r16 265/70 nokian nordman s suv
# 1744             r15 235/75 sailun ice blazer wst1 ship
# 1764                          r17 225/45 triangle tr777
# 1939                         r17 225/45 triangle tr 777
# 1942                          r17 215/55 triangle tr777
# 2224                          r19 225/45 triangle pl 02
# 2257                          r19 235/50 triangle pl 02
# 2290             r15 195/60 nokian hakkapeliitta 8 ship
# 2296                          r17 235/55 triangle tr257
# 2342                        r14 185/65 pirelli ice zero
# 2356  r20 285/50 nokian tyres116t xl hakkapeliitta 8...
#
#       Топ1 уровень cos сходства 1_4  Топ2 уровень cos сходства 1_4  \
# 25                           74.359                         74.359
# 219                          44.331                         40.254
# 410                          77.868                         77.868
# 428                          90.625                         90.625
# 659                          87.879                         87.879
# 675                          80.013                         78.967
# 678                          42.683                         42.553
# 695                          60.664                         60.583
# 738                          75.683                         74.247
# 761                          74.852                         74.852
# 999                          64.715                         64.489
# 1068                         78.866                         77.643
# 1107                         64.162                         63.386
# 1146                         91.892                         91.892
# 1147                         73.721                         73.721
# 1317                         81.786                         81.595
# 1319                         88.571                         88.571
# 1393                         81.786                         81.595
# 1446                         89.072                         87.143
# 1582                         71.506                         71.506
# 1666                         59.537                         58.897
# 1684                         75.305                         74.684
# 1744                         58.003                         57.448
# 1764                         61.189                         58.897
# 1939                         60.315                         58.897
# 1942                         59.878                         59.878
# 2224                         64.860                         63.742
# 2257                         67.983                         64.600
# 2290                         70.513                         70.513
# 2296                         57.279                         57.279
# 2342                         63.943                         63.943
# 2356                         74.587                         74.348
#
#                  Cos сходство топ1 совпадение 1-4  \
# 25              r15 195/50 pirelli formula energy
# 219          r15 205/70 kapsen rw506 100t xl ship
# 410               r16 215/70 nokian nordman s suv
# 428             r16 235/70 royalblack royal sport
# 659                 r19 235/45 sailun atrezzo zsr
# 675              r18 235/65 sunwide conquest 106h
# 678              r17 235/45 97w massimo ottima p1
# 695                  r17 245/40 95w xl ultra arz5
# 738              r18 215/55 kapsen k3000 99w xl z
# 761       r17 235/45 kapsen s2000 headking xl 97w
# 999                      r19 235/40 triangle pl02
# 1068                r18 255/45 ilink l zeal56 99w
# 1107         r19 275/35 triangle100y th201 tl m+s
# 1146       r18 255/35 royalblack royal perfomance
# 1147             r19 255/35 ilink l zeal56 96w xl
# 1317            r14 185/60 pirelli formula energy
# 1319               r15 185/60 nokian nordman rs 2
# 1393            r15 185/65 pirelli formula energy
# 1446                 r15 195/65 nokian nordman sx
# 1582       r16 205/55 nokian hakkapeliitta 8 ship
# 1666                    r16 225/70 triangle tr257
# 1684                r14 175/70 nokian nordman rs2
# 1744  r17 235/65 sailun ice blazer wst3 104t ship
# 1764                    r17 215/45 triangle tr757
# 1939                r17 235/45 triangle snow pl01
# 1942                    r17 225/55 triangle tr777
# 2224                    r19 245/45 triangle th201
# 2257                    r19 255/50 triangle th201
# 2290            r16 235/70 nokian hakkapeliitta 7
# 2296                    r18 235/55 triangle tr257
# 2342                  r17 225/45 pirelli ice zero
# 2356       r17 215/50 nokian hakkapeliitta 8 ship
#
#                 Cos сходство топ2 совпадение 1-4
# 25             r14 175/65 pirelli formula energy
# 219    r13 155/70 75t kapsen h202 comfortmax a/s
# 410              r16 225/70 nokian nordman s suv
# 428            r16 245/70 royalblack royal sport
# 659                r18 235/45 sailun atrezzo zsr
# 675             r17 265/65 sunwide conquest 112h
# 678        r14 175/65 massimo mas winter 79 82 t
# 695                        r18 245/40 ultra arz4
# 738        r16 215/55 xl 97w kapsen k3000 papide
# 761      r17 225/45 xl 94w kapsen s2000 headking
# 999                    r18 235/40 triangle th201
# 1068               r19 245/45 ilink l zeal56 98w
# 1107                   r20 275/35 triangle th201
# 1146      r20 255/45 royalblack royal perfomance
# 1147            r20 245/35 ilink l zeal56 95w xl
# 1317         r15 185/60 pirelli formula ice ship
# 1319               r15 185/60 nokian nordman rs2
# 1393         r14 185/65 pirelli formula ice ship
# 1446               r15 195/60 nokian nordman rs2
# 1582      r16 225/55 nokian hakkapeliitta 8 ship
# 1666                   r16 225/70 triangle tr259
# 1684           r17 235/65 nokian nordman rs2 suv
# 1744           r17 215/45 sailun ice blazer wst1
# 1764                  r17 225/45 triangle tr 777
# 1939                   r17 235/65 triangle tr777
# 1942                  r17 215/55 triangle tr 777
# 2224                    r18 245/45 triangle pl02
# 2257                    r19 235/50 triangle pl02
# 2290           r14 185/70 nokian hakkapeliitta 7
# 2296                   r19 235/55 triangle tr259
# 2342                 r14 185/65 pirelli ice zero
# 2356  r18 285/60 nokian hakkapeliitta 8 suv ship

# %%
df_remaining[(df_remaining['Топ1 уровень cos сходства 1_3']>97)&(df_remaining['Топ1 уровень cos сходства 1_3']<=100)].head(20)
# Out:
#                       Наименование обработанное  \
# 1               r13 155/70 royalblack royalmile
# 11          r13 175/70 royalblack royal comfort
# 12              r13 175/70 royalblack royal eco
# 28                r14 175/65 kama breeze nk 132
# 32   r14 175/65 viatti strada asimmetrico v 130
# 44            r14 175/65 pirelli formula energy
# 49                r14 185/60 kama breeze nk 132
# 52   r14 185/60 viatti strada asimmetrico v 130
# 61            r14 185/60 pirelli formula energy
# 66                r14 185/65 kama breeze nk 132
# 67   r14 185/65 viatti strada asimmetrico v 130
# 76            r14 185/65 pirelli formula energy
# 82                r14 175/70 sailun atrezzo eco
# 87                r14 185/70 kama breeze nk 132
# 89   r14 185/70 viatti strada asimmetrico v 130
# 91                r14 185/70 sailun atrezzo eco
# 103  r15 195/50 viatti strada asimmetrico v 130
# 117  r15 185/55 viatti strada asimmetrico v 130
# 118             r15 185/55 royalblack royal eco
# 128  r15 195/55 viatti strada asimmetrico v 130
#
#      token_set_ratio уровень сходства  \
# 1                              87.097
# 11                            100.000
# 12                            100.000
# 28                            100.000
# 32                            100.000
# 44                            100.000
# 49                            100.000
# 52                            100.000
# 61                            100.000
# 66                            100.000
# 67                            100.000
# 76                            100.000
# 82                            100.000
# 87                            100.000
# 89                            100.000
# 91                            100.000
# 103                           100.000
# 117                           100.000
# 118                           100.000
# 128                           100.000
#
#               token_set_ratio лучшее совпадение  \
# 1               r13 155/70 royalblack royal a/s
# 11          r13 175/70 royalblack royal comfort
# 12              r13 175/70 royalblack royal eco
# 28           r14 175/65 kama h 82 breeze nk 132
# 32   r14 175/65 viatti strada asimmetrico v 130
# 44            r14 175/65 pirelli formula energy
# 49                r14 185/60 kama breeze nk 132
# 52   r14 185/60 viatti strada asimmetrico v 130
# 61            r14 185/60 pirelli formula energy
# 66           r14 185/65 kama h 86 breeze nk 132
# 67   r14 185/65 viatti strada asimmetrico v 130
# 76            r14 185/65 pirelli formula energy
# 82            r14 175/70 88t sailun atrezzo eco
# 87           r14 185/70 kama t 88 breeze nk 132
# 89   r14 185/70 viatti strada asimmetrico v 130
# 91                r14 185/70 sailun atrezzo eco
# 103  r15 195/50 viatti strada asimmetrico v 130
# 117  r15 185/55 viatti strada asimmetrico v 130
# 118             r15 185/55 royalblack royal eco
# 128  r15 195/55 viatti strada asimmetrico v 130
#
#      Топ1 уровень cos сходства 1_3  Топ2 уровень cos сходства 1_3  \
# 1                            100.0                         91.265
# 11                           100.0                         92.958
# 12                           100.0                         92.063
# 28                           100.0                         88.372
# 32                           100.0                         92.754
# 44                           100.0                         90.566
# 49                           100.0                        100.000
# 52                           100.0                         92.754
# 61                           100.0                         90.566
# 66                           100.0                         88.372
# 67                           100.0                         92.754
# 76                           100.0                         90.566
# 82                           100.0                         88.889
# 87                           100.0                         88.372
# 89                           100.0                         92.754
# 91                           100.0                         88.889
# 103                          100.0                         92.867
# 117                          100.0                         92.958
# 118                          100.0                         90.636
# 128                          100.0                         92.958
#
#                Cos сходство топ1 совпадение 1-3  \
# 1              r13 155/70 royalblack royal mile
# 11          r13 175/70 royalblack royal comfort
# 12              r13 175/70 royalblack royal eco
# 28                r14 175/65 kama breeze nk 132
# 32   r14 175/65 viatti strada asimmetrico v 130
# 44            r14 175/65 pirelli formula energy
# 49                r14 185/60 kama breeze nk 132
# 52   r14 185/60 viatti strada asimmetrico v 130
# 61            r14 185/60 pirelli formula energy
# 66                r14 185/65 kama breeze nk 132
# 67   r14 185/65 viatti strada asimmetrico v 130
# 76            r14 185/65 pirelli formula energy
# 82                r14 175/70 sailun atrezzo eco
# 87                r14 185/70 kama breeze nk 132
# 89   r14 185/70 viatti strada asimmetrico v 130
# 91                r14 185/70 sailun atrezzo eco
# 103  r15 195/50 viatti strada asimmetrico v 130
# 117  r15 185/55 viatti strada asimmetrico v 130
# 118             r15 185/55 royalblack royal eco
# 128  r15 195/55 viatti strada asimmetrico v 130
#
#                Cos сходство топ2 совпадение 1-3  \
# 1         r13 155/70 75t royal black royal mile
# 11          r14 175/70 royalblack royal comfort
# 12              r14 175/70 royalblack royal eco
# 28                r14 185/65 kama breeze nk 132
# 32   r14 185/65 viatti strada asimmetrico v 130
# 44            r14 185/65 pirelli formula energy
# 49                r14 185/60 kama breeze nk 132
# 52   r14 185/65 viatti strada asimmetrico v 130
# 61            r14 185/65 pirelli formula energy
# 66                r14 185/60 kama breeze nk 132
# 67   r14 185/60 viatti strada asimmetrico v 130
# 76            r14 185/60 pirelli formula energy
# 82                r14 185/70 sailun atrezzo eco
# 87                r14 175/70 kama breeze nk 132
# 89    r14 175/70 viatti strada asimmetrico v130
# 91                r14 175/70 sailun atrezzo eco
# 103  r15 195/55 viatti strada asimmetrico v 130
# 117  r15 195/55 viatti strada asimmetrico v 130
# 118             r15 185/65 royalblack royal eco
# 128  r15 185/55 viatti strada asimmetrico v 130
#
#      Топ1 уровень cos сходства 1_4  Топ2 уровень cos сходства 1_4  \
# 1                            100.0                         90.132
# 11                           100.0                         92.157
# 12                           100.0                         91.111
# 28                           100.0                         85.714
# 32                           100.0                         91.089
# 44                           100.0                         88.462
# 49                           100.0                        100.000
# 52                           100.0                         92.079
# 61                           100.0                         88.462
# 66                           100.0                         85.714
# 67                           100.0                         92.079
# 76                           100.0                         89.744
# 82                           100.0                         86.364
# 87                           100.0                         85.714
# 89                           100.0                         91.089
# 91                           100.0                         86.364
# 103                          100.0                         91.181
# 117                          100.0                         91.262
# 118                          100.0                         89.016
# 128                          100.0                         91.262
#
#                Cos сходство топ1 совпадение 1-4  \
# 1              r13 155/70 royalblack royal mile
# 11          r13 175/70 royalblack royal comfort
# 12              r13 175/70 royalblack royal eco
# 28                r14 175/65 kama breeze nk 132
# 32   r14 175/65 viatti strada asimmetrico v 130
# 44            r14 175/65 pirelli formula energy
# 49                r14 185/60 kama breeze nk 132
# 52   r14 185/60 viatti strada asimmetrico v 130
# 61            r14 185/60 pirelli formula energy
# 66                r14 185/65 kama breeze nk 132
# 67   r14 185/65 viatti strada asimmetrico v 130
# 76            r14 185/65 pirelli formula energy
# 82                r14 175/70 sailun atrezzo eco
# 87                r14 185/70 kama breeze nk 132
# 89   r14 185/70 viatti strada asimmetrico v 130
# 91                r14 185/70 sailun atrezzo eco
# 103  r15 195/50 viatti strada asimmetrico v 130
# 117  r15 185/55 viatti strada asimmetrico v 130
# 118             r15 185/55 royalblack royal eco
# 128  r15 195/55 viatti strada asimmetrico v 130
#
#                Cos сходство топ2 совпадение 1-4
# 1               r13 155/70 royalblack royal a/s
# 11          r14 175/70 royalblack royal comfort
# 12              r14 175/70 royalblack royal eco
# 28                r14 185/65 kama breeze nk 132
# 32   r14 185/65 viatti strada asimmetrico v 130
# 44            r14 185/65 pirelli formula energy
# 49                r14 185/60 kama breeze nk 132
# 52   r15 185/60 viatti strada asimmetrico v 130
# 61            r14 185/65 pirelli formula energy
# 66                r14 185/60 kama breeze nk 132
# 67   r15 185/65 viatti strada asimmetrico v 130
# 76            r15 185/65 pirelli formula energy
# 82                r14 185/70 sailun atrezzo eco
# 87                r14 185/60 kama breeze nk 132
# 89    r14 175/70 viatti strada asimmetrico v130
# 91                r14 175/70 sailun atrezzo eco
# 103  r15 195/55 viatti strada asimmetrico v 130
# 117  r15 195/55 viatti strada asimmetrico v 130
# 118             r15 185/65 royalblack royal eco
# 128  r15 185/55 viatti strada asimmetrico v 130

# %% [markdown]
# Пристальный анализ дал понять, что нужно выбирать топ1 косинусное сходство в зависимости от разницы между уровнем сходства топ1 и топ2 значения. Если разница между ур. схожести топ1 и топ2 значениями у метрики с 1-4 n-граммами выше, чем таковая у метрики с 1-3 n-граммами, то выбираем первую. Иначе - вторую. И token_set_ratio используем при значениях уровня сходства выше 97.
#
# Создадим взвешенное сходство

# %%
df_remaining['Взвешенное сходство'] = None
df_remaining['Уровень взвеш. сходства'] = None

for index, row in df_remaining.iterrows():
    # Если топ1 ур. cos сходства у 1-3 n-грамм больше или равен, чем у token_set_ratio и больше 97, то устанавливаем сходство соответствующее этому значению.
    if row['Топ1 уровень cos сходства 1_3']>=row['token_set_ratio уровень сходства'] and row['Топ1 уровень cos сходства 1_3']>=97:
        df_remaining.at[index, 'Взвешенное сходство'] = row['Cos сходство топ1 совпадение 1-3']
        df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_3']
        
    # Применяем token_set_ratio, если уровень сходства у него больше 97
    elif row['token_set_ratio уровень сходства']>=97:
        df_remaining.at[index, 'Взвешенное сходство'] = row['token_set_ratio лучшее совпадение']
        df_remaining.at[index, 'Уровень взвеш. сходства'] = row['token_set_ratio уровень сходства']
        
    # Если лучшие косинусные совпадения для 1-3n-грамм и для 1-4n-грамм одинаковы, во взвешенное значение ставим одно из них
    elif row['Cos сходство топ1 совпадение 1-3']==row['Cos сходство топ1 совпадение 1-4']:
        df_remaining.at[index, 'Взвешенное сходство'] = row['Cos сходство топ1 совпадение 1-3']
        df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_3']
        
    # Если топ1 косинусное совпадение для 1-3n-грамм совпадает с топ2 кос. совпадением для 1-4n-грамм, аналогично в обратную сторону - рассчитываем какая пара выдаст большее
    # среднее значение и устанавливаем наименование ему соответствующее
    elif row['Cos сходство топ1 совпадение 1-3']==row['Cos сходство топ2 совпадение 1-4'] and row['Cos сходство топ2 совпадение 1-3']==row['Cos сходство топ1 совпадение 1-4']:
        mean_cos_sim_top2ngr3_top1ngr4 = (row['Топ2 уровень cos сходства 1_3'] + row['Топ1 уровень cos сходства 1_4']) / 2
        mean_cos_sim_top1ngr3_top2ngr4 = (row['Топ1 уровень cos сходства 1_3'] + row['Топ2 уровень cos сходства 1_4']) / 2
        
        if mean_cos_sim_top2ngr3_top1ngr4 >= mean_cos_sim_top1ngr3_top2ngr4:
            df_remaining.at[index, 'Взвешенное сходство'] = row['Cos сходство топ1 совпадение 1-4']
            df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_4']
        else:
            df_remaining.at[index, 'Взвешенное сходство'] = row['Cos сходство топ1 совпадение 1-3']
            df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_3']
            
    # Иначе     
    else:
        diff_cos_sim_top1ngr4_top2ngr4 = abs(row['Топ1 уровень cos сходства 1_4'] - row['Топ2 уровень cos сходства 1_4'])
        diff_cos_sim_top1ngr3_top1ngr3 = abs(row['Топ1 уровень cos сходства 1_3'] - row['Топ2 уровень cos сходства 1_3'])
        
        # Если разница топ1 и топ2 сходства для 1-4n-грамм больше чем аналогичная разница для 1-3n-грамм
        # устанавливает наименование, соответствующее топ1 совпадению для 1-4n-грамм
        if diff_cos_sim_top1ngr4_top2ngr4 > diff_cos_sim_top1ngr3_top1ngr3:
            df_remaining.at[index, 'Взвешенное сходство'] = row['Cos сходство топ1 совпадение 1-4']
            df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_4']
            
        # Если разница топ1 и топ2 сходства нулевая в обоих случаях, то проверяет является ли лучшее совпадение token_set_ratio в списке всех косинусных топ1-2 совпадений.
        # Если является - устанавливает наименование, соответствующее лучшему совпадению token_set_ratio
        # Если нет - устанавливает топ1 совпадение 1-4n-грамм
        elif diff_cos_sim_top1ngr4_top2ngr4==0 and diff_cos_sim_top1ngr3_top1ngr3==0:
            if row['token_set_ratio лучшее совпадение'] in [row['Cos сходство топ1 совпадение 1-4'],row['Cos сходство топ2 совпадение 1-4'],row['Cos сходство топ1 совпадение 1-3'],row['Cos сходство топ2 совпадение 1-3']]:
                df_remaining.at[index, 'Взвешенное сходство'] = row['token_set_ratio лучшее совпадение']
                df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_3'] if (row['Топ1 уровень cos сходства 1_3'] >= row['token_set_ratio уровень сходства']) else row['token_set_ratio уровень сходства']
            else:
                df_remaining.at[index, 'Взвешенное сходство'] = row['Cos сходство топ1 совпадение 1-4']
                df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_3'] if (row['Топ1 уровень cos сходства 1_3'] >= row['Топ1 уровень cos сходства 1_4']) else row['Топ1 уровень cos сходства 1_4']
                
        # Если разница топ1 и топ2 сходства для 1-4n-грамм меньше, чем аналогичная разница для 1-3n-грамм
        else:
            df_remaining.at[index, 'Взвешенное сходство'] = row['Cos сходство топ1 совпадение 1-3']
            df_remaining.at[index, 'Уровень взвеш. сходства'] = row['Топ1 уровень cos сходства 1_3']

# %% [markdown]
# ### Посмотрим какие взвешенные сходства получаются, когда значения token_set_ratio отличаются от значений косинусных сходств

# %%
df_remaining[df_remaining['token_set_ratio лучшее совпадение']!=df_remaining['Cos сходство топ1 совпадение 1-3']].sample(3, random_state=111)
# Out:
#                   Наименование обработанное  token_set_ratio уровень сходства  \
# 513  r17 215/45 royalblack royal explorer 2                            91.892
# 362       r16 215/65 yokohama bluearth ae50                            92.537
# 496           r17 205/40 sailun atrezzo zsr                           100.000
#
#         token_set_ratio лучшее совпадение  Топ1 уровень cos сходства 1_3  \
# 513  r19 245/45 royalblack royal explorer                         92.524
# 362    r16 215/60 yokohama blu earth ae01                         96.444
# 496     r17 205/40 84y sailun atrezzo zsr                         88.889
#
#      Топ2 уровень cos сходства 1_3  \
# 513                         86.667
# 362                         87.514
# 496                         87.671
#
#                  Cos сходство топ1 совпадение 1-3  \
# 513  r17 215/45 royal black royal explorer ii 91w
# 362         r16 215/65 yokohama blu earth a ae 50
# 496                 r17 245/40 sailun atrezzo zsr
#
#          Cos сходство топ2 совпадение 1-3  Топ1 уровень cos сходства 1_4  \
# 513  r19 245/45 royalblack royal explorer                         92.233
# 362  r16 215/60 yokohama bluearth a ae 50                         94.495
# 496     r17 205/40 84y sailun atrezzo zsr                         86.364
#
#      Топ2 уровень cos сходства 1_4  \
# 513                         85.582
# 362                         83.450
# 496                         85.280
#
#                  Cos сходство топ1 совпадение 1-4  \
# 513  r17 215/45 royal black royal explorer ii 91w
# 362         r16 215/65 yokohama blu earth a ae 50
# 496                 r17 245/40 sailun atrezzo zsr
#
#          Cos сходство топ2 совпадение 1-4  \
# 513  r19 245/45 royalblack royal explorer
# 362  r16 215/60 yokohama bluearth a ae 50
# 496     r17 205/40 84y sailun atrezzo zsr
#
#                               Взвешенное сходство Уровень взвеш. сходства
# 513  r17 215/45 royal black royal explorer ii 91w                  92.524
# 362         r16 215/65 yokohama blu earth a ae 50                  96.444
# 496             r17 205/40 84y sailun atrezzo zsr                   100.0

# %% [markdown]
# Получились следующие случаи, разберем их:
# 1) Для значения "r17 215/45 royalblack royal explorer 2" метод token_set_ratio подтянул "r19 245/45 royalblack royal explorer", косинусные сходства обоих методов подтянули "r17 215/45 royal black royal explorer ii 91w". Значение у token_set_ratio ошиблось в диаметре колеса (19 вместо 17), и размере (245/45 вместо 215/45). Косинусное сходство сработало без ошибок ("ii" соответствует "2", а параметр "91w" просто не указан в наименовании нашей выгрузки). Взвешенное сходство использовало совпадение косинусного сходства, все верно.
# 2) Для значения "r16 215/65 yokohama bluearth ae50" метод token_set_ratio подтянул "r16 215/60 yokohama blu earth ae01", косинусные сходства обоих методов подтянули "r16 215/65 yokohama blu earth a ae 50". Значение у token_set_ratio ошиблось в размере (215/60 вместо 215/65) и параметре "ae50", найдя вместо этого значение с параметром "ae01". Косинусное сходство сработало без ошибок. Взвешенное сходство использовало совпадение косинусного сходства, все верно.
# 3) Для значения "r17 205/40 sailun atrezzo zsr" метод token_set_ratio подтянул "r17 205/40 84y sailun atrezzo zsr", косинусные сходства обоих методов подтянули "r17 245/40 sailun atrezzo zsr" (топ1 значение) и на топ2 поставили значение как и у token_set_ratio. Метод token_set_ratio сработал без ошибок (аналогично первому случаю для косинусного сходства, параметр "84y" просто не указан в наименовании нашей выгрузки). Косинусное сходство для топ1 совпадений ошиблось в размере, но топ2 подтянули верно. Взвешенное сходство опять отработало верно.

# %% [markdown]
# Таким образом, взвешенное сходство использует плюсы всех методов и выбирает наилучший метод для конкретного случая.

# %%
final_df = df_remaining.iloc[:,[0,-2,-1]].copy()

# %%
final_df = final_df.merge(df_1C.iloc[:,1:3], left_on='Взвешенное сходство', right_on='Наименование обработанное', suffixes=('','_1C'), how='left').drop('Наименование обработанное_1C', axis=1)

# %%
final_df = final_df.sort_values(by=['Взвешенное сходство']).reset_index(drop=True)

# %%
final_df
# Out:
#                    Наименование обработанное  \
# 0      r13 155/70 kapsen h202 comfortmax a/s
# 1      r15 235/75 kapsen h201 touringmax a/s
# 2              r13 155/70 sailun atrezzo eco
# 3              r13 155/70 roadx rxfrost wh12
# 4      r13 155/70 royalblack royal winter hp
# ...                                      ...
# 2396           r22 285/45 ilink speedking 07
# 2397  r22 285/45 kapsen rs26 practicalmax hp
# 2398  r22 295/40 kapsen rs26 practicalmax hp
# 2399               r22 295/40 sunwide rs one
# 2400    r22 315/35 ilink wintervorhut stud 2
#
#                                   Взвешенное сходство Уровень взвеш. сходства  \
# 0           r13 155/70 75t kapsen h202 comfortmax a/s                   100.0
# 1           r13 155/70 75t kapsen h202 comfortmax a/s                  38.468
# 2                   r13 155/70 75t sailun atrezzo eco                   100.0
# 3                   r13 155/70 roadx rxfrost wh12 75t                   100.0
# 4                     r13 155/70 royalblack royal a/s                  85.526
# ...                                               ...                     ...
# 2396            r22 285/45 ilink speedking 07 114v xl                   100.0
# 2397  r22 285/45 xl 114w kapsen rs26 practicalmax h/p                  87.287
# 2398  r22 295/40 xl 112w kapsen rs26 practicalmax h/p                  87.287
# 2399               r22 295/40z sunwide rs one 112w xl                  79.183
# 2400    r22 315/35 ilink wintervorhut stud ii 111t xl                  97.143
#
#               Код
# 0     ЦБ-00007311
# 1     ЦБ-00007311
# 2     ЦБ-00006440
# 3     ЦБ-00007708
# 4     ЦБ-00005134
# ...           ...
# 2396  ЦБ-00007893
# 2397  ЦБ-00007418
# 2398  ЦБ-00007417
# 2399  ЦБ-00007568
# 2400  ЦБ-00007768
#
# [2401 rows x 4 columns]

# %% [markdown]
# Количество строк в нашей выгрузке немного увеличилось. Произошло это по причине того, что в выгрузке из 1C некоторые значения присутствовали несколько раз и имели несколько кодов.

# %%
final_df[final_df.duplicated(subset=['Наименование обработанное'], keep=False)]
# Out:
#                       Наименование обработанное  \
# 97                r14 185/60 kama breeze nk 132
# 98                r14 185/60 kama breeze nk 132
# 217                 r15 185/60 kama euro hk 236
# 218                 r15 185/60 kama euro hk 236
# 376                   r15 195/65 kama irbis 505
# 377                   r15 195/65 kama irbis 505
# 378               r15 195/65 kama breeze nk 132
# 379               r15 195/65 kama breeze nk 132
# 380                 r15 195/65 kama euro hk 129
# 381                 r15 195/65 kama euro hk 129
# 419               r15 205/65 kama breeze nk 132
# 420               r15 205/65 kama breeze nk 132
# 791   r16 235/70 triangle group tr777 snow lion
# 792   r16 235/70 triangle group tr777 snow lion
# 793   r16 215/70 triangle group tr777 snow lion
# 794   r16 215/70 triangle group tr777 snow lion
# 1338                 r17 225/65 triangle te 301
# 1339                 r17 225/65 triangle te 301
# 1372        r17 235/45 triangle group trin pl01
# 1373        r17 235/45 triangle group trin pl01
# 1374        r17 235/45 triangle group trin pl02
# 1375        r17 235/45 triangle group trin pl02
# 1560        r18 225/40 triangle group trin pl01
# 1561        r18 225/40 triangle group trin pl02
# 1562        r18 225/40 triangle group trin pl01
# 1563        r18 225/40 triangle group trin pl02
# 1690        r18 235/45 triangle group trin pl02
# 1691        r18 235/45 triangle group trin pl02
# 1692        r18 235/45 triangle group trin pl01
# 1693        r18 235/45 triangle group trin pl01
#
#                 Взвешенное сходство Уровень взвеш. сходства          Код
# 97    r14 185/60 kama breeze nk 132                   100.0  00-00000066
# 98    r14 185/60 kama breeze nk 132                   100.0  00-00000786
# 217        r15 185/60 kama evro 236                   73.08  00-00000808
# 218        r15 185/60 kama evro 236                   73.08  00-00000122
# 376       r15 195/65 kama 505 irbis                   100.0  00-00000862
# 377       r15 195/65 kama 505 irbis                   100.0  00-00003403
# 378   r15 195/65 kama breeze nk 132                   100.0  00-00000861
# 379   r15 195/65 kama breeze nk 132                   100.0  00-00000197
# 380        r15 195/65 kama evro 129                   73.08  00-00000224
# 381        r15 195/65 kama evro 129                   73.08  00-00000863
# 419   r15 205/65 kama breeze nk 132                   100.0  00-00000234
# 420   r15 205/65 kama breeze nk 132                   100.0  00-00000870
# 791       r16 215/70 triangle tr777                  64.255  ЦБ-00000849
# 792       r16 215/70 triangle tr777                  64.255  ЦБ-00004310
# 793       r16 215/70 triangle tr777                   100.0  ЦБ-00004310
# 794       r16 215/70 triangle tr777                   100.0  ЦБ-00000849
# 1338      r17 225/65 triangle te301                   100.0  00-00001003
# 1339      r17 225/65 triangle te301                   100.0  00-00000565
# 1372       r17 235/45 triangle pl01                   100.0  ЦБ-00000905
# 1373       r17 235/45 triangle pl01                   100.0  00-00002704
# 1374       r17 235/45 triangle pl01                  73.672  00-00002704
# 1375       r17 235/45 triangle pl01                  73.672  ЦБ-00000905
# 1560       r18 225/40 triangle pl01                   100.0  ЦБ-00000917
# 1561       r18 225/40 triangle pl01                  73.672  ЦБ-00000917
# 1562       r18 225/40 triangle pl01                   100.0  ЦБ-00004590
# 1563       r18 225/40 triangle pl01                  73.672  ЦБ-00004590
# 1690       r18 235/45 triangle pl01                  73.672  00-00000639
# 1691       r18 235/45 triangle pl01                  73.672  ЦБ-00000922
# 1692       r18 235/45 triangle pl01                   100.0  00-00000639
# 1693       r18 235/45 triangle pl01                   100.0  ЦБ-00000922

# %% [markdown]
# В выгрузке 1С содержатся далеко не все значения соответствующие значениями нашей выгрузке, поэтому, разумеется, будут и значения взвешенных сходств, одинаковые для разных наименований:

# %%
final_df[final_df.duplicated(subset=['Взвешенное сходство'], keep=False)]
# Out:
#                   Наименование обработанное  \
# 0     r13 155/70 kapsen h202 comfortmax a/s
# 1     r15 235/75 kapsen h201 touringmax a/s
# 4     r13 155/70 royalblack royal winter hp
# 5           r13 155/70 royalblack royal eco
# 9                   r13 155/70 kapsen hd918
# ...                                     ...
# 2366           r21 275/45 arivo ultra arz 5
# 2389          r22 275/40 ilink speedking 07
# 2390          r22 265/40 ilink speedking 07
# 2395          r20 275/45 ilink speedking 07
# 2396          r22 285/45 ilink speedking 07
#
#                             Взвешенное сходство Уровень взвеш. сходства  \
# 0     r13 155/70 75t kapsen h202 comfortmax a/s                   100.0
# 1     r13 155/70 75t kapsen h202 comfortmax a/s                  38.468
# 4               r13 155/70 royalblack royal a/s                  85.526
# 5               r13 155/70 royalblack royal a/s                  91.622
# 9                   r13 175/70 82t kapsen hd918                  71.275
# ...                                         ...                     ...
# 2366                      r21 275/45 ultra arz5                   79.43
# 2389      r22 265/40 ilink speedking 07 106v xl                   80.48
# 2390      r22 265/40 ilink speedking 07 106v xl                   100.0
# 2395      r22 285/45 ilink speedking 07 114v xl                  70.969
# 2396      r22 285/45 ilink speedking 07 114v xl                   100.0
#
#               Код
# 0     ЦБ-00007311
# 1     ЦБ-00007311
# 4     ЦБ-00005134
# 5     ЦБ-00005134
# 9     ЦБ-00007569
# ...           ...
# 2366  ЦБ-00003728
# 2389  ЦБ-00007892
# 2390  ЦБ-00007892
# 2395  ЦБ-00007893
# 2396  ЦБ-00007893
#
# [788 rows x 4 columns]

# %% [markdown]
# Возьмем 10 случайных строк и посмотрим как хорошо отработал наш алгоритм:

# %%
final_df.sample(10, random_state=29)
# Out:
#                 Наименование обработанное  \
# 1474        r17 245/40 sailun atrezzo zsr
# 1557       r18 225/40 rydanz roadster r02
# 565        r16 205/55 arivo premio arzero
# 1093    r17 215/50 sailun ice blazer wst3
# 621     r16 205/60 sailun ice blazer wst3
# 444       r15 205/70 royalblack royal ice
# 238          r15 185/65 massimo ottima p1
# 380           r15 195/65 kama euro hk 129
# 115   r14 185/60 yokohama ice guard ig50+
# 1081    r17 205/50 nokian hakkapeliitta 8
#
#                              Взвешенное сходство Уровень взвеш. сходства  \
# 1474               r17 245/40 sailun atrezzo zsr                   100.0
# 1557       r18 225/40 rydanz roadster r02 xl 92w                   100.0
# 565                     r16 205/55 premio arzero                   100.0
# 1093  r17 215/50 sailun ice blazer wst3 95t ship                   100.0
# 621   r16 205/60 sailun ice blazer wst3 96t ship                   100.0
# 444          r15 205/70 royalblack royal ice 96s                   100.0
# 238             r15 185/65 88h massimo ottima p1                   100.0
# 380                     r15 195/65 kama evro 129                   73.08
# 115           r14 185/60 yokohama ice guard ig50                   100.0
# 1081      r17 215/50 nokian hakkapeliitta 8 ship                  84.419
#
#               Код
# 1474  00-00000589
# 1557  ЦБ-00007274
# 565   ЦБ-00004027
# 1093  ЦБ-00006756
# 621   ЦБ-00006899
# 444   ЦБ-00007212
# 238   ЦБ-00007239
# 380   00-00000224
# 115   00-00000080
# 1081  ЦБ-00004144

# %% [markdown]
# Все наименования идеально подтянулись. Можно проверить последние 2 наименования:

# %%
df_remaining[df_remaining['Наименование обработанное'].isin(['r17 205/50 nokian hakkapeliitta 8','r14 185/60 yokohama ice guard ig50+'])]
# Out:
#                 Наименование обработанное  token_set_ratio уровень сходства  \
# 1320  r14 185/60 yokohama ice guard ig50+                            98.551
# 1754    r17 205/50 nokian hakkapeliitta 8                            90.141
#
#            token_set_ratio лучшее совпадение  Топ1 уровень cos сходства 1_3  \
# 1320      r14 185/60 yokohama ice guard ig50                        100.000
# 1754  r17 215/50 nokian hakkapeliitta 8 ship                         84.419
#
#       Топ2 уровень cos сходства 1_3        Cos сходство топ1 совпадение 1-3  \
# 1320                         87.936      r14 185/60 yokohama ice guard ig50
# 1754                         77.791  r17 215/50 nokian hakkapeliitta 8 ship
#
#             Cos сходство топ2 совпадение 1-3  Топ1 уровень cos сходства 1_4  \
# 1320  r14 185/60 yokohama iceguard stud ig55                        100.000
# 1754      r16 195/50 nokian hakkapeliitta r2                         82.353
#
#       Топ2 уровень cos сходства 1_4        Cos сходство топ1 совпадение 1-4  \
# 1320                         85.934      r14 185/60 yokohama ice guard ig50
# 1754                         76.743  r17 215/50 nokian hakkapeliitta 8 ship
#
#             Cos сходство топ2 совпадение 1-4  \
# 1320  r14 185/60 yokohama iceguard stud ig55
# 1754      r16 195/50 nokian hakkapeliitta r2
#
#                          Взвешенное сходство Уровень взвеш. сходства
# 1320      r14 185/60 yokohama ice guard ig50                   100.0
# 1754  r17 215/50 nokian hakkapeliitta 8 ship                  84.419

# %% [markdown]
# Подтянулись наилучшие варианты наименований, все методы выбрали одинаковые варианты. И ручной поиск в выгрузке 1C подтвердил это, другие похожие наименования в ней отсутствуют.

# %% [markdown]
# Теперь посмотрим какой процент совпадений с уровнем схожести в 100 баллов у нас получился

# %%
percentage = (final_df[final_df['Уровень взвеш. сходства']==100].shape[0]/final_df.shape[0])*100
print(f"Процент строк с уровнем взвешенного сходства равным 100: {percentage:.1f}%")
# Out:
# Процент строк с уровнем взвешенного сходства равным 100: 53.2%

# %% [markdown]
# ### Сравнение с таблицей, где сотрудник подтягивал наименования из 1С вручную

# %%
df_for_test = pd.read_excel('Подтянутые коды сотрудником.xlsx')

# %%
df_for_test
# Out:
#                                Наименование  \
# 0         R13 155/70 RoyalBlack Royal ECO
# 1           R13 155/70 RoyalBlack ROYALMILE
# 2             R13 155/70 Sailun Atrezzo Eco
# 3     R13 155/70 Kapsen H202 ComfortMax A/S
# 4                   R13 155/70 Kapsen HD918
# ...                                     ...
# 2381         R21 315/40 ILINK SnowGripper 2
# 2382   R21 315/40 Arivo Winmaster ProX ARW5
# 2383         R22 275/40 ILINK SnowGripper 2
# 2384   R22 275/40 ILINK WinterVorhut Stud 2
# 2385   R22 315/35 ILINK WinterVorhut Stud 2
#
#                                   Наименование в 1С     Код в 1С
# 0                                               NaN          NaN
# 1            R13 155/70  75T ROYAL BLACK ROYAL MILE  ЦБ-00007482
# 2                 R13 155/70 75T Sailun ATREZZO ECO  ЦБ-00006440
# 3        R13 155/70  75T KAPSEN H202 ComfortMax A/S  ЦБ-00007311
# 4                                               NaN          NaN
# ...                                             ...          ...
# 2381        R21 315/40 ILINK SNOWGRIPPER II 115H XL  ЦБ-00007605
# 2382                 R21 315/40 Winmaster ProX ARW5  00-00000002
# 2383        R22 275/40 ILINK SNOWGRIPPER II 107H XL  ЦБ-00007606
# 2384   R22 275/40 ILINK WINTERVORHUT STUD Ⅱ 107T XL  ЦБ-00007701
# 2385  R22 315/35 ILINK WINTERVORHUT STUD II 111T XL  ЦБ-00007768
#
# [2386 rows x 3 columns]

# %% [markdown]
# Оставим только строки, в которых есть код из 1C.
#
# Так же применим к наименованиям в этой таблице функции по очистке текста, которые мы применяли для своих датафреймов.

# %%
df_for_test_len_befor_delete_na = df_for_test.shape[0]
df_for_test = df_for_test[df_for_test['Код в 1С'].notna()].copy()
df_for_test = df_for_test.rename(columns={'Код в 1С':'Код в 1С_test'})
df_for_test = process_column(df_for_test, 'Наименование', 'Наименование обработанное_test')
df_for_test = process_column(df_for_test, 'Наименование в 1С', 'Наименование в 1С обработанное_test')
df_for_test.drop_duplicates(['Наименование','Наименование в 1С','Код в 1С_test'], inplace=True)
print(f"Количество наименований, отсутствующих в 1С выгрузке: {df_for_test_len_befor_delete_na - df_for_test.shape[0]}")
# Out:
# Количество наименований, отсутствующих в 1С выгрузке: 546

# %% [markdown]
# Теперь посмотрим какой процент у нас совпадает с наименованиями выставленными в ручную сотрудником.
#
# Подтянем значения, ключом будет наименование

# %%
final_df_merged = final_df.merge(df_for_test.iloc[:,-3:], left_on='Наименование обработанное', right_on='Наименование обработанное_test',how='left')
final_df_merged
# Out:
#                    Наименование обработанное  \
# 0      r13 155/70 kapsen h202 comfortmax a/s
# 1      r15 235/75 kapsen h201 touringmax a/s
# 2              r13 155/70 sailun atrezzo eco
# 3              r13 155/70 roadx rxfrost wh12
# 4      r13 155/70 royalblack royal winter hp
# ...                                      ...
# 2396           r22 285/45 ilink speedking 07
# 2397  r22 285/45 kapsen rs26 practicalmax hp
# 2398  r22 295/40 kapsen rs26 practicalmax hp
# 2399               r22 295/40 sunwide rs one
# 2400    r22 315/35 ilink wintervorhut stud 2
#
#                                   Взвешенное сходство Уровень взвеш. сходства  \
# 0           r13 155/70 75t kapsen h202 comfortmax a/s                   100.0
# 1           r13 155/70 75t kapsen h202 comfortmax a/s                  38.468
# 2                   r13 155/70 75t sailun atrezzo eco                   100.0
# 3                   r13 155/70 roadx rxfrost wh12 75t                   100.0
# 4                     r13 155/70 royalblack royal a/s                  85.526
# ...                                               ...                     ...
# 2396            r22 285/45 ilink speedking 07 114v xl                   100.0
# 2397  r22 285/45 xl 114w kapsen rs26 practicalmax h/p                  87.287
# 2398  r22 295/40 xl 112w kapsen rs26 practicalmax h/p                  87.287
# 2399               r22 295/40z sunwide rs one 112w xl                  79.183
# 2400    r22 315/35 ilink wintervorhut stud ii 111t xl                  97.143
#
#               Код Код в 1С_test          Наименование обработанное_test  \
# 0     ЦБ-00007311   ЦБ-00007311   r13 155/70 kapsen h202 comfortmax a/s
# 1     ЦБ-00007311           NaN                                     NaN
# 2     ЦБ-00006440   ЦБ-00006440           r13 155/70 sailun atrezzo eco
# 3     ЦБ-00007708   ЦБ-00007708           r13 155/70 roadx rxfrost wh12
# 4     ЦБ-00005134           NaN                                     NaN
# ...           ...           ...                                     ...
# 2396  ЦБ-00007893   ЦБ-00007893           r22 285/45 ilink speedking 07
# 2397  ЦБ-00007418   ЦБ-00007418  r22 285/45 kapsen rs26 practicalmax hp
# 2398  ЦБ-00007417   ЦБ-00007417  r22 295/40 kapsen rs26 practicalmax hp
# 2399  ЦБ-00007568   ЦБ-00007568               r22 295/40 sunwide rs one
# 2400  ЦБ-00007768   ЦБ-00007768    r22 315/35 ilink wintervorhut stud 2
#
#                   Наименование в 1С обработанное_test
# 0           r13 155/70 75t kapsen h202 comfortmax a/s
# 1                                                 NaN
# 2                   r13 155/70 75t sailun atrezzo eco
# 3                   r13 155/70 roadx rxfrost wh12 75t
# 4                                                 NaN
# ...                                               ...
# 2396            r22 285/45 ilink speedking 07 114v xl
# 2397  r22 285/45 xl 114w kapsen rs26 practicalmax h/p
# 2398  r22 295/40 xl 112w kapsen rs26 practicalmax h/p
# 2399               r22 295/40z sunwide rs one 112w xl
# 2400    r22 315/35 ilink wintervorhut stud ii 111t xl
#
# [2401 rows x 7 columns]

# %% [markdown]
# Удалим строки с пустыми подтянутыми значениями - это те, по которым сотрудник не нашел кода в 1C и мы их удалили из df_for_test

# %%
final_df_merged = final_df_merged[final_df_merged['Код в 1С_test'].notna()]

# %%
percentage = ((final_df_merged[(final_df_merged['Взвешенное сходство']==final_df_merged['Наименование в 1С обработанное_test'])].shape[0])/final_df_merged.shape[0])*100
print(f"Процент наименований моего алгоритма, совпавших с наименованиями, проставленными сотрудником: {percentage:.1f}%. \n")
# Out:
# Процент наименований моего алгоритма, совпавших с наименованиями, проставленными сотрудником: 93.3%.

# %% [markdown]
# Значения с различающимися наименованиями из 1C:

# %%
final_df_merged[~(final_df_merged['Взвешенное сходство']==final_df_merged['Наименование в 1С обработанное_test'])].iloc[:,[0,1,-1]].reset_index(drop=True)
# Out:
#                   Наименование обработанное  \
# 0           r13 155/70 royalblack royalmile
# 1                  r13 175/70 kama euro 519
# 2               r14 175/65 kama euro hk 129
# 3            r14 175/65 pirelli formula ice
# 4               r14 175/70 kama euro hk 129
# ..                                      ...
# 120              r20 275/40 ilink l zeal 56
# 121       r20 275/40 sailun atrezzo zsr suv
# 122       r20 315/35 sailun atrezzo zsr suv
# 123            r21 275/40 arivo ultra arz 5
# 124  r22 285/35 kapsen rs26 practicalmax hp
#
#                                  Взвешенное сходство  \
# 0                   r13 155/70 royalblack royal mile
# 1                   r13 175/70 kama t 82 evro 519 sh
# 2                           r14 175/65 kama euro 129
# 3                  r14 175/65 pirelli formula energy
# 4                           r14 175/70 kama euro 129
# ..                                               ...
# 120              r20 275/40 ilink l zeal56 106w xl z
# 121          r20 275/40z 106y sailun atrezzo zsr suv
# 122                r20 315/35 sailun atrezzo zsr suv
# 123                            r21 275/45 ultra arz5
# 124  r22 285/35 xl 106w kapsen rs26 practicalmax h/p
#
#                  Наименование в 1С обработанное_test
# 0              r13 155/70 75t royal black royal mile
# 1                           r14 175/70 kama euro 129
# 2                      r14 175/65 kama h 82 evro 129
# 3                r14 175/70 pirelli formula ice ship
# 4                      r14 175/70 kama h 84 evro 129
# ..                                               ...
# 120                r20 275/45 ilink l zeal56 110v xl
# 121          r20 275/45z 110y sailun atrezzo zsr suv
# 122           r20 315/35 110y sailun atrezzo zsr suv
# 123                    r21 275/40 107w xl ultra arz5
# 124  r21 285/35 xl 105y kapsen rs26 practicalmax h/p
#
# [125 rows x 3 columns]

# %% [markdown]
# 125 наименований различаются
#
# ##### Но что можно заметить: мой алгоритм сработал лучше, чем ручная подстановка сотрудником.
# 1) В 0 строке мое сходство 100%, у значения сотрудника же оно отличается на значение "75t"
# 2) В 1 строке у значения сотрудника неверен диаметр колеса
# 3) Во 2 строке все идентично, разница в параметрах (которые не указаны в нашей выгрузке), в 1С было несколько аналогичных значений
# 4) В 3 строке у значения сотрудника неверен размер шины
# 5) В 4 строке так же все идентично, разница в параметрах (которые не указаны в нашей выгрузке), в 1С было несколько аналогичных значений
# 6) В 120 строке все идентично, разница в параметрах (которые не указаны в нашей выгрузке), в 1С было несколько аналогичных значений
# 7) В 121 строке аналогичная ситуация
# 8) В 122 строке аналогичная ситуация
# 9) В 123 строке мой метод ошибся в размере шины (45 вместо 40)
# 10) В 124 строке у значения сотрудника неверен диаметр колеса, мой метод отработал верно

# %% [markdown]
# Таким образом из рассмотренных наименований мой метод ошибся 1 раз, но показал лучшие совпадения, чем у сотрудника, 4 раза, остальные 5 раз результаты "even" (на одном уровне), то есть невозможно выявить лучшего кандидата, из-за отсутствия параметров в нашей выгрузке

# %% [markdown]
# Это еще раз подтверждает, что человеческий фактор при длительной ручной работе дает о себе знать, в этих случаях лучше использовать такие алгоритмы как разработанный мной.

# %% [markdown]
# Рассмотрим единственное неверное совпадение, полученное моим алгоритмом

# %%
df_remaining[df_remaining['Наименование обработанное']=='r21 275/40 arivo ultra arz 5']
# Out:
#          Наименование обработанное  token_set_ratio уровень сходства  \
# 1234  r21 275/40 arivo ultra arz 5                            81.633
#
#      token_set_ratio лучшее совпадение  Топ1 уровень cos сходства 1_3  \
# 1234             r21 275/45 ultra arz5                         73.952
#
#       Топ2 уровень cos сходства 1_3 Cos сходство топ1 совпадение 1-3  \
# 1234                         67.442            r21 275/45 ultra arz5
#
#      Cos сходство топ2 совпадение 1-3  Топ1 уровень cos сходства 1_4  \
# 1234    r21 275/40 107w xl ultra arz5                         70.049
#
#       Топ2 уровень cos сходства 1_4 Cos сходство топ1 совпадение 1-4  \
# 1234                         64.002            r21 275/45 ultra arz5
#
#      Cos сходство топ2 совпадение 1-4    Взвешенное сходство  \
# 1234    r21 275/40 107w xl ultra arz5  r21 275/45 ultra arz5
#
#      Уровень взвеш. сходства
# 1234                  73.952

# %% [markdown]
# Видно, что все три метода, token_set_ratio и cos сходства, подтянули именно значение с неверным размером шины. Косинусное сходство поставило верный вариант на топ2 уровень сходства. Но в данном случае сложно было бы поставить это наименование на первое место, так как 7 дополнительных символов "107w xl" (и особенное влияние здесь оказали цифры, "107") в выгрузке из 1C значительно уменьшают возможность верного сопоставления.

# %% [markdown]
# Если бы у нас были столбцы со значениями диаметра колеса и размера шин, то можно было бы сделать следующий алгоритм:
#
# 1) Полное сопоставление значений диаметра колеса и размера шин
# 2) Получение сходства,где параметры колес полностью идентичны, а нечеткое сравнение выполняется в окне полностью совпадающих параметров (это бы, к тому же, ускорило бы работу алгоритма)
# 3) Рассчет взвешенного сходства

# %% [markdown]
# У нас этих столбцов нет, но для решения этой проблемы можно было бы "вытаскивать" диаметр колеса и размер шины из первых двух слов наименования. Но подробное изучение выгрузок дало понять, что это невозможно, так как не обязательно, что эти значения будут находиться в первых двух словах. Также у этих значений бывает самый разный формат в разных выгрузках. Здесь можно было бы делать нечеткое сравнение в окне полного сопоставления диаметра и размера только в случае, если они (диаметр и размер) верного формата, а для остальных случаев использовать нечеткое сравнение без такого окна. Я бы это реализовал, если бы эта задача настоящей, а не кейсовой. В данном же кейсе я хочу сохранить созданный мной алгоритм для дальнейшего широкого использования, с возможностью его корректировки под конкретную задачу.

# %% [markdown]
# Или же можно было бы на размеченных данных обучить нейронную сеть или другие алгоритмы машинного обучения. Но, как видно из сопоставлений сотрудником, он делал довольно много ошибок, ошибаясь намного чаще, чем мой алгоритм. И как известно, размечать данные это дорого, при том что для каждой новой задачи размечать данные нужно заново. Мой алгоритм потребует (если вообще потрубет) лишь небольшой корректировки, в зависимости от наличия дополнительных столбцов, на основе которых будут создаваться окна полного сопоставления. В основном он будет работать хорошо и без корректировки.

# %% [markdown]
# #### Таким образом, был создан алгоритм взвешенного нечеткого сопоставления, которые использует методы token_set_ratio (рассчет расстояния Левенштейна между двумя множествами токенов, при игнорировании порядка слов и дубликатов) и косинусное сходство различных n-грамм
#
# #### Данный алгоритм показал высокий результат, который находится на одном уровне с длительным (сопровожденным неточностями) ручным сопоставлением.
#
# #### Еще один важный плюс моего алгоритма - скорость работы. Я использовал матричное скалярное произведение csr-матриц для рассчета косинусного сходства, а матричное скалярное произведение очень хорошо оптимизировано в numpy и выполняется очень быстро. Основная же масса известных методов нечеткого сравнения занимает относительно много времени при работе с большими массивами данных.
#
# #### Идея создания такого алгоритма через n-граммы пришла после того, как я заметил, что существующие и мной известные методы в основной массе не очень хорошо справляются с задачей нечеткого сопоставлений. Изначально я просто хотел протестировать этот алгоритм и больших надежд не питал, но он оказался очень хорош, особенно взвешенная версия.

# %% [markdown]
# ________________
# ______________
# __________

# %% [markdown]
# ## Дополнение:
# ## Я создал класс в отдельном модуле для этого алгоритма, теперь его легко можно использовать в 2 строки кода

# %%
from WeighedFuzzyNickAlt import WeighedFuzzyTextProcessor

# %% [markdown]
# Загрузим заново выгрузки, чтоб отменить все примененные к ним изменения в предыдущем коде

# %%
df = pd.read_csv('Gr_Krasn.csv',encoding='Windows-1251', low_memory=False)

# %%
df_1C = pd.read_excel('Данные из 1C.xlsx')

# %%
processor = WeighedFuzzyTextProcessor(df, df_1C)
result_df = processor.calculate_similarity()

# %%
result_df.sample(random_state=229)
# Out:
#                         Наименование       Наименование обработанное  \
# 2129  R18 245/40 Rydanz Nordica NR01  r18 245/40 rydanz nordica nr01
#
#       token_set_ratio уровень сходства      token_set_ratio лучшее совпадение  \
# 2129                             100.0  r18 245/40 rydanz nordica nr01 97v xl
#
#       Топ1 уровень cos сходства 1_3  Топ2 уровень cos сходства 1_3  \
# 2129                         91.132                         81.833
#
#            Cos сходство топ1 совпадение 1-3  \
# 2129  r18 245/40 rydanz nordica nr01 97v xl
#
#            Cos сходство топ2 совпадение 1-3  Топ1 уровень cos сходства 1_4  \
# 2129  r18 225/40 rydanz nordica nr01 92v xl                         90.862
#
#       Топ2 уровень cos сходства 1_4       Cos сходство топ1 совпадение 1-4  \
# 2129                         79.344  r18 245/40 rydanz nordica nr01 97v xl
#
#            Cos сходство топ2 совпадение 1-4  \
# 2129  r18 225/40 rydanz nordica nr01 92v xl
#
#                         Взвешенное сходство Уровень взвеш. сходства
# 2129  r18 245/40 rydanz nordica nr01 97v xl                   100.0

# %% [markdown]
# Все отлично работает

# %% [markdown]
# Еще хочу заметить, что в класс добавлены docstring'и, то есть грубо говоря документация класса. Можно нажать с помощью shift+tab (в зависимости от используемой программы) и посмотреть нужную информацию, в том числе в каждом реализованном методе класса.

# %% [markdown]
# Также можно использовать отдельно методы класса и для обычного текста. Вот, например, реализация разделения на 1-3 n-граммы слова "текст"

# %%
processor.create_ngrams('текст', (1,3))
# Out:
# ['т', 'е', 'к', 'с', 'т', 'те', 'ек', 'кс', 'ст', 'тек', 'екс', 'кст']
